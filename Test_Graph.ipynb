# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from pyvis import network as pvnet
import networkx as nx
from networkx import MultiDiGraph
from enum import Enum, auto
from datetime import datetime
from typing import Self, Optional, Union, Tuple

# %% [markdown]
# # Raw to Standardized Form Conversion Code (DO NOT EDIT !!!)

# %% [markdown]
# ## Create an Enum for Entities

# %%
class Ent(Enum):

    ENTITY      = 0
    LOCATION    = auto()
    TRANSPORTER = auto()
    SUPPLIER    = auto()
    MATERIAL    = auto()
    PRODUCER    = auto()
    PRODUCT     = auto()
    DISTRIBUTOR = auto()
    CUSTOMER    = auto()

# %% [markdown]
# ## The Entity Database
#
# - A comman database for storing all entities while graph creation using `numpy.array` in a dict
#
# - Each entity will be stored in unique array, with its name as key

# %%
class EntityDatabase:

    # Initializer
    def __init__(
        self,
        db_path:str = 'dataset',  # Path to store the database
        db_name:str = datetime.now().strftime("%Y-%m-%d %H-%M-%S")  # Filename to save
    ):

        # Name
        self.name = 'Entity Database'

        # Store path and name in variables
        self.db_path = db_path
        self.db_name = db_name

        # Create empty dict
        self.storage = {}

        # Populate according to the Entities in `Ent`
        for entity in Ent:
            self.storage[entity.name] = np.empty((0,), dtype=object)

    # Add entity to the storage
    # TODO: Check for Duplication
    def add(self, entity: 'Entity'):
        type = entity.type

        self.storage[type.name] = np.append(self.storage[type.name], entity)
    
    # Print the complete Entity Database
    def show(self) -> Self:
        print(f'{self.name}')

        cnt = 1
        for entity_name in self.storage:
            for entity in self.storage[entity_name]:
                print(f'\t[{cnt:3}] {entity}')
                cnt += 1
        return self
    
    def __str__(self):
        return f"<Class '{self.__class__.__name__}'|{self.name}>"

    # Reset
    def reset(self):
        self.__init__()

# %%
# Create the DB
DB = EntityDatabase()

# %% [markdown]
# ## Entity (Base Class)

# %%
class Entity:

    # Initializer
    def __init__(self, name: Optional[str] = None):

        # Name of the Entity
        self.name = name

        # Type of Entity
        self.type = Ent.ENTITY

        # Properties
        self._price = None
        self._time = None
        self._capacity = None
        self._location = None
        self._supplier = None
        self._extra_properties = dict()
    
    # String Output
    def __str__(self):
        return f"<Class '{self.__class__.__name__}'|{self._name}>"
    
    # The price of entity (per item)
    def price(self, value: float) -> Self:
        self._price = value
        return self

    # The time required (in Hours)
    def time(self, time_required: int) -> Self:
        self._time = time_required
        return self
    
    # Set the capacity of the Entity
    def capacity(self, capa: float) -> Self:
        self._capacity = capa
        return self
    
    # Set the location of the Entity
    def at(self, loc: 'Location') -> Self:
        self._location = loc
        return self
    
    # Entity Supplied by
    def by(self, supplied_by: 'Supplier') -> Self:
        self._supplier += (supplied_by, )
        return self
    
    # Extra Porps
    def extra_properties(self, properties: dict) -> Self:

        self._extra_properties = properties
        return self

    # Get Node: Return all the info to generate a node in the graph
    def get_Node(self) -> dict:

        node_data = {}

        if self._extra_properties:
            for prop, value in self._extra_properties.items():
                node_data[prop] = value
        
        return node_data
    
    # Get NodeLink: Returns the edge info between two nodes, this entity connects
    def get_NodeLink(self) -> dict:
        raise NotImplementedError

# %% [markdown]
# ## Location

# %%
class Location(Entity):

    # Initializer
    def __init__(self, name: Optional[str]):
        super().__init__(name)

        # Type of Entity
        self.type = Ent.LOCATION

        # Default Name:
        if name is None:
            n = len(DB.storage[self.type.name])
            self.name = f"l{n}"

        # Add this to DB
        DB.add(self)
    
    def __str__(self) -> str:

        return f'{self.type.name:10}  {self.name}'

# %% [markdown]
# ## Transporter

# %%
class Transporter(Entity):

    # Initializer
    def __init__(
        self,
        from_location: Location,
        to_location: Location,
        name: Optional[str] = None,
        rate: Optional[float] = None,
        required_time: Optional[int] = None,
        cap: Optional[float] = None
    ):
        super().__init__(name)

        # Type of Entity
        self.type = Ent.TRANSPORTER

        # Default Name:
        if name is None:
            n = len(DB.storage[self.type.name])
            self.name = f"t{n}"

        # Properties
        self._price          = rate
        self._time           = required_time  # In Hours
        self._capacity       = cap
        self._from           = from_location
        self._to             = to_location

        # Add this to DB
        DB.add(self)

    # Get NodeLink Info
    def get_NodeLink(self) -> dict:
        
        # A dict with all properties
        link_data = {
            'fromLoc': self._from.name,
            'toLoc': self._to.name
        }

        if self._price:
            link_data['price'] = self._price
        
        if self._time:
            link_data['time'] = self._time
        
        if self._capacity:
            link_data['capacity'] = self._capacity
        
        return link_data

    # Show the Entity
    def __str__(self):

        info = f'{self.type.name:10}  {self.name} | {self._from.name} ==> {self._to.name}'

        if self._price:
            info += f' | {self._price}/per unit'
        
        if self._time:
            info += f' | {self._time} hrs'
        
        if self._capacity:
            info += f' | {self._capacity} units capacity'
        
        info += " |"

        return info

# %% [markdown]
# ## Supplier

# %%
class Supplier(Entity):
    
    # Initializer
    def __init__(
        self,
        name: Optional[str] = None,
        loc: Optional[Location] = None,
        varPrice: Optional[float] = None,
        required_time: Optional[int] = None,
        cap: Optional[float] = None
    ):
        super().__init__(name)

        # Type of Entity
        self.type = Ent.SUPPLIER

        # Default Name:
        if name is None:
            n = len(DB.storage[self.type.name])
            self.name = f"s{n}"

        # Properties
        self._price          = varPrice
        self._time           = required_time  # In Hours
        self._capacity       = cap
        self._location       = loc
        self._supplied_entities = tuple()

        # Add this to DB
        DB.add(self)

    # Add the supplied Entities
    def supplies(self, supplied_entity: Union['Material', 'Product', tuple]) -> Self:
        
        if not isinstance(supplied_entity, tuple):
            supplied_entity = (supplied_entity, )
        
        self._supplied_entities += supplied_entity

        # Remove Duplicates
        self._supplied_entities = tuple(set(self._supplied_entities))

        # Add this to product / Material as well
        for entity in supplied_entity:
            if self not in entity._supplier:
                entity.by(self)

        return self

    # Print detials
    def __str__(self) -> str:
        info = f'{self.type.name:10}  {self.name}'

        if self._location:
            info += f' | {self._location.name}'
        
        if self._price:
            info += f' | {self._price}/unit'
        
        if self._time:
            info += f' | {self._time} hrs'
        
        if self._capacity:
            info += f' | {self._capacity} units capacity'
        
        if self._supplied_entities:
            info += f' | Entities Supplied: {", ".join([entity.name for entity in self._supplied_entities])}'

        info += " |"
        return info

    # Get Node Info
    def get_Node(self) -> dict:
        
        # A dict with all properties
        node_data = super().get_Node()

        if self._price:
            node_data['vCost'] = self._price
        
        if self._time:
            node_data['time'] = self._time
        
        if self._capacity:
            node_data['capacity'] = self._capacity
        
        return node_data

    # Get Node Info
    def get_NodeLink(self) -> dict:

        link_data = {}
        
        # A dict with all properties
        if self._supplied_entities:
            link_data['supplies'] = self._supplied_entities

        return link_data

# %% [markdown]
# ## Material

# %%
class Material(Entity):

    # Initializer
    def __init__(
        self,
        name: Optional[str] = None,
        price: Optional[float] = None,
        supplied_by: Optional[Supplier] = tuple()
    ):
        super().__init__(name)

        # Type of Entity
        self.type = Ent.MATERIAL

        # Default Name:
        if name is None:
            n = len(DB.storage[self.type.name])
            self.name = f"m{n}"

        # Add Properties
        self._price = price

        if not isinstance(supplied_by, tuple):
            supplied_by = (supplied_by, )
        self._supplier = supplied_by

        # Required for
        self._required_for = tuple()
        self._produced_by = tuple()

        # Add this to DB
        DB.add(self)
    
    # Show detials
    def __str__(self) -> str:
        info = f'{self.type.name:10}  {self.name}'

        if self._location:
            info += f' | {self._location.name}'
        
        if self._price:
            info += f' | {self._price}/unit'
        
        if self._time:
            info += f' | {self._time} hrs'
        
        if self._capacity:
            info += f' | {self._capacity} units capacity'
        
        if self._supplier:
            info += f' | Supplied by: {", ".join([entity.name for entity in self._supplier])}'
        
        if self._required_for:
            info += f' | Required for: {", ".join([entity.name for entity in self._required_for])}'

        if self._extra_properties:
            info += f' | {" | ".join([str(prop)+": "+str(value) for prop, value in self._extra_properties.items()])}'

        if self._produced_by:
            info += f' | Produced by: {", ".join([entity.name for entity in self._produced_by])}'

        info += " |"
        return info

    # Add Supplier
    def by(self, suppliers: Union[Supplier, 'Producer', tuple]) -> Self:

        if not isinstance(self._supplier, tuple):
            self._supplier = tuple()
        
        if not isinstance(suppliers, tuple):
            suppliers = (suppliers, )

        # Distinguish between Producer and Supplier
        for entity in suppliers:

            if entity.type == Ent.PRODUCER:
                self._produced_by += (entity, )
            
            elif entity.type in (Ent.SUPPLIER, Ent.DISTRIBUTOR):
                self._supplier += (entity, )

        # Remove Duplicates
        self._supplier = tuple(set(self._supplier))
        self._produced_by = tuple(set(self._produced_by))

        # Add to the Suppliers
        for entity in suppliers:

            if entity.type == Ent.SUPPLIER and self not in entity._supplied_entities:
                entity.supplies(self)
            
            elif entity.type == Ent.PRODUCER and self not in entity._products:
                entity.produces(self)

        return self

    # Add product
    def required_for(self, products: Union['Product', Tuple['Product', ...]]) -> Self:

        if not isinstance(products, tuple):
            products = (products, )
        
        self._required_for += products

        # Remove Duplicates
        self._required_for = tuple(set(self._required_for))

        # Add to the Products
        for product in products:
            if self not in product.materials_required:
                product.ingredient(self)
        
        return self

    # Get Node Info
    def get_Node(self) -> dict:
        
        # A dict with all properties
        node_data = super().get_Node()

        if self._price:
            node_data['vCost'] = self._price

        return node_data

    # Get Node Info
    def get_NodeLink(self) -> dict:
        
        # A dict with all properties
        link_data = {}

        if self._supplier:
            link_data['supplied_by'] = self._supplier

        if self._required_for:
            link_data['required_for'] = self._required_for

        if self._produced_by:
            link_data['produced_by'] = self._produced_by

        return link_data

# %% [markdown]
# ## Product

# %%
class PriceNotProviced(Exception):
    pass

# %%
class Product(Entity):

    # Initializer
    def __init__(
        self,
        name: Optional[str] = None,
        price: Optional[float] = None,
    ):
        super().__init__(name)

        # Type of Entity
        self.type = Ent.PRODUCT

        # Default Name:
        if name is None:
            n = len(DB.storage[self.type.name])
            self.name = f"p{n}"

        # Add Properties
        self._price = price
        self._supplier = tuple()
        self.materials_required = tuple()
        self._produced_by = tuple()

        # Add this to DB
        DB.add(self)

    # Add required Ingrdients
    def ingredient(self, materials_required: Union[Material, Tuple[Material, ...]]) -> Self:

        if not isinstance(self.materials_required, tuple):
            self.materials_required = tuple()
        
        elif not isinstance(materials_required, tuple):
            materials_required = (materials_required,)
        
        self.materials_required += materials_required

        # Remove Duplicates
        self.materials_required = tuple(set(self.materials_required))

        # Add to the Materials
        for material in materials_required:
            material: Material
            if self not in material._required_for:
                material.required_for(self)

        return self
    
    # Add the Producer of Supplier for the product
    def by(self, supplied_by: Union['Distributor', 'Supplier', 'Producer', Tuple]) -> Self:

        if not isinstance(self._supplier, tuple):
            self._supplier = tuple()
        
        if not isinstance(supplied_by, tuple):
            supplied_by = (supplied_by, )

        # Distinguish between Producer and Supplier
        for entity in supplied_by:

            if entity.type == Ent.PRODUCER:
                self._produced_by += (entity, )
            
            elif entity.type in (Ent.SUPPLIER, Ent.DISTRIBUTOR):
                self._supplier += (entity, )

        # Remove Duplicates
        self._supplier = tuple(set(self._supplier))
        self._produced_by = tuple(set(self._produced_by))

        # Add to the Suppliers
        for entity in supplied_by:

            if entity.type == Ent.SUPPLIER and self not in entity._supplied_entities:
                entity.supplies(self)
            
            elif entity.type == Ent.PRODUCER and self not in entity._products:
                entity.produces(self)

        return self

    # Show detials
    def __str__(self) -> str:
        info = f'{self.type.name:10}  {self.name}'
        
        if self._price:
            info += f' | {self._price}/unit'
        
        if self._time:
            info += f' | {self._time} hrs'
        
        if self._capacity:
            info += f' | {self._capacity} units capacity'
        
        if self.materials_required:
            info += f' | Ingredients: {", ".join([m.name for m in self.materials_required])}'
        
        if self._supplier:
            info += f' | Suppliers: {", ".join([supplier.name for supplier in self._supplier])}'
        
        if self._produced_by:
            info += f' | Producers: {", ".join([producer.name for producer in self._produced_by])}'


        info += " |"
        return info

    # Get Node Info
    def get_Node(self) -> dict:
        
        # A dict with all properties
        node_data = super().get_Node()

        if self._price:
            node_data['vCost'] = self._price
        
        return node_data

    # Get Node Info
    def get_NodeLink(self) -> dict:
        
        # A dict with all properties
        link_data = {}

        if self._supplier:
            link_data['supplied_by'] = self._supplier
        
        if self._produced_by:
            link_data['produced_by'] = set(self._produced_by)
        
        if self.materials_required:
            link_data['materials_required'] = [mat for mat in self.materials_required]

        return link_data

# %% [markdown]
# ## Producer / Manufacturer

# %%
class Producer(Entity):
    
    # Initializer
    def __init__(
        self,
        name: Optional[str] = None,
        varCost: Optional[float] = None,
        capa: Optional[int] = None
    ):
        super().__init__(name)

        # Type of Entity
        self.type = Ent.PRODUCER

        # Default Name:
        if name is None:
            n = len(DB.storage[self.type.name])
            self.name = f"P{n}"

        # Add Properties
        self._varCost = varCost
        self._location = None
        self._capacity = capa
        self._supplies_to = tuple()
        self._products = tuple()

        # Add this to DB
        DB.add(self)

    # Set the VarCost
    def varCost(self, varcost: float) -> Self:
        self._varCost = varcost
        return self

    # Show detials
    def __str__(self) -> str:
        info = f'{self.type.name:10}  {self.name}'

        if self._location:
            info += f' | {self._location.name}'
        
        if self._price:
            info += f' | {self._price}/unit'
        
        if self._varCost:
            info += f' | {self._varCost}/unit'
        
        if self._time:
            info += f' | {self._time} hrs'
        
        if self._capacity:
            info += f' | {self._capacity} units capacity'

        if self._supplies_to:
                info += f' | Supplies to: {", ".join([s.name for s in self._supplies_to])}'
        
        if self._products:
            info += f' | Produces: {", ".join([entity.name for entity in self._products])}'

        info += " |"

        return info

    # Add products produced
    def produces(self, products: Union[Product, Tuple[Product, ...]]) -> Self:

        # Convert to tuple
        if not isinstance(products, tuple):
            products = (products, )

        # Add
        self._products += products

        # Remove Duplicates
        self._products = tuple(set(self._products))

        # Add to the Products
        for product in products:
            if self not in product._produced_by:
                print(product)
                product.by(self)

        return self

    # Add the Supplying Destinations
    def supplies(self, supplies_to: 'Distributor') -> Self:
        
        # Check if Tuple
        if not isinstance(supplies_to, tuple):
            supplies_to = (supplies_to,)
        
        # Add
        self._supplies_to += supplies_to

        # Remove Duplicates
        self._supplies_to = tuple(set(self._supplies_to))

        # Add the Distributors
        for dest in supplies_to:
            dest: Distributor
            if self not in dest._suppliers:
                dest.supplier(self)

        return self

    # Get Node Info
    def get_Node(self) -> dict:
        
        # A dict with all properties
        node_data = super().get_Node()

        if self._price:
            node_data['vCost'] = self._price
        
        if self._time:
            node_data['time'] = self._time
        
        if self._capacity:
            node_data['capacity'] = self._capacity
        
        return node_data

    # Get Node Info
    def get_NodeLink(self) -> dict:
        
        # A dict with all properties
        link_data = {}

        if self._supplies_to:
            link_data['supplies_to'] = self._supplies_to
        
        if self._products:
            link_data['produces'] = self._products

        return link_data

# %% [markdown]
# ## The Distributors

# %%
class Distributor(Producer):

    # Initializer
    def __init__(
        self,
        name: Optional[str] = None,
        varCost: Optional[float] = None,
        capa: Optional[int] = None
    ):
        super().__init__(name)

        # Type of Entity
        self.type = Ent.DISTRIBUTOR

        # Default Name:
        if name is None:
            n = len(DB.storage[self.type.name])
            self.name = f"d{n}"

        # Add Properties
        self._varCost = varCost
        self._location = None
        self._capacity = capa
        self._suppliers = tuple()
        self._inventory = tuple()

        # Add this to DB
        DB.add(self)
    
    # Show detials
    def __str__(self) -> str:
        info = f'{self.type.name:10}  {self.name}'

        if self._location:
            info += f' | {self._location.name}'
        
        if self._price:
            info += f' | {self._price}/unit'
        
        if self._time:
            info += f' | {self._time} hrs'
        
        if self._capacity:
            info += f' | {self._capacity} units capacity'
        
        if self._suppliers:
            info += f' | Suppliers: {", ".join([entity.name for entity in self._suppliers])}'

        if self._inventory:
            info += f' | Inventory: {", ".join([entity.name for entity in self._inventory])}'

        info += " |"
        return info

    # Add Suppliers
    def supplier(self, suppliers: Union[Producer, Tuple[Producer, ...]]) -> Self:
        
        # Check if not tuple
        if not isinstance(suppliers, tuple):
            suppliers = (suppliers, )
        
        # Add
        self._suppliers += suppliers

        # Remove Duplicates
        self._suppliers = tuple(set(self._suppliers))

        # Add to Producers
        for supplier in suppliers:
            if self not in supplier._supplies_to:
                supplier.supplies(self)
            
            # Add to Products
            for product in supplier._products:

                product : Product

                # Add to Inventory
                if product not in self._products:
                    self._inventory += (product, )

                if self not in product._supplier:
                    product.by(self)
        
        return self

    # Node Link
    def get_NodeLink(self) -> dict:
        link_data =  super().get_NodeLink()

        if self._suppliers:
            link_data['supplier'] = self._suppliers
        
        if self._inventory:
            link_data['supplies'] = self._inventory
        
        return link_data

# %% [markdown]
# ## Customer

# %%
class Customer(Entity):

    # Initializer
    def __init__(
        self,
        name: Optional[str] = None,
        product: Optional[Product] = None,
        demand: Optional[int] = None,
        time: Optional[int] = None
    ):
        super().__init__(name)

        # Type of Entity
        self.type = Ent.CUSTOMER

        # Default Name:
        if name is None:
            n = len(DB.storage[self.type.name])
            self.name = f"c{n}"

        # Add Properties
        self._demand = demand
        self._location = None
        self._time = time
        self._product = product

        # Add this to DB
        DB.add(self)
    
    # Show detials
    def __str__(self) -> str:
        info = f'{self.type.name:10}  {self.name}'

        if self._location:
            info += f' | {self._location.name}'
        
        if self._product:
            info += f' | Demands: {self._product.name}'
        
        if self._demand:
            info += f' | {self._demand} units'
        
        if self._time:
            info += f' | {self._time} hrs'
        
        info += " |"
        return info

     # Get Node Info
    def get_Node(self) -> dict:
        
        # A dict with all properties
        node_data = super().get_Node()

        if self._demand:
            node_data['demand'] = self._demand
        
        return node_data

    def demand(self, demand: float) -> Self:
        self._demand = demand
        return self

    def product(self, prod: Product) -> Self:
        self._product = prod
        return self
    
    # Get Node Info
    def get_NodeLink(self) -> dict:
        
        # A dict with all properties
        link_data = {
            'demands': self._product
        }
        return link_data

# %% [markdown]
# ## Supply Chain Network Class

# %%
class SupplyNetwork:

    def __init__(self, name: Optional[str] = 'Supply Network'):

        # Set the Name
        self.name = name

        # The main Database
        self.db = None

        # Set different graphs to none
        self.transportation_graph = None
        self.supply_flow_graph    = None
        self.knowledge_graph      = None
    
    # Add the Supply Chain DB
    def add_DB(self, db: EntityDatabase) -> None:
        self.db = db
    
    # Create a Transportation Graph
    def create_transportation_graph(self, as_label:bool = True) -> Tuple[MultiDiGraph, dict]:

        # Loop through all transportation nodes
        transportation_data = self.db.storage[Ent.TRANSPORTER.name]

        graph_dict = {}
        for transporter in transportation_data:
            transporter: Transporter
            link_data = transporter.get_NodeLink()

            # Get from and to Node
            fromNode = link_data.pop('fromLoc')
            toNode   = link_data.pop('toLoc')

            # Check if fromNode is present in the graph_data
            if not fromNode in graph_dict:
                graph_dict[fromNode] = {}
            
            # Check if to is present in the fromNode dict
            if not toNode in graph_dict[fromNode]:
                graph_dict[fromNode][toNode] = {}
            
            # Get the current number of links between nodes
            n = len(graph_dict[fromNode][toNode])

            # Create Label (or title)
            label = f"{transporter.name}\n"
            for key, value in link_data.items():
                label += f"{key}:{value}\n"
            
            # Add label (or title) to link data
            if as_label:
                link_data['label'] = label[:-1]
            else:
                link_data['title'] = label[:-1]
            
            # Add to Graph dict
            graph_dict[fromNode][toNode][n] = link_data

        self.transportation_graph = MultiDiGraph(graph_dict)
        return self.transportation_graph, graph_dict

    # Create supply Flow
    def create_supply_flow(self, as_label:bool = True) -> MultiDiGraph: 

        # Get all players
        supplier_data       = self.db.storage[Ent.SUPPLIER.name]
        producer_data       = self.db.storage[Ent.PRODUCER.name]
        distributor_data    = self.db.storage[Ent.DISTRIBUTOR.name]
        customer_data       = self.db.storage[Ent.CUSTOMER.name]
        material_data       = self.db.storage[Ent.MATERIAL.name]
        product_data        = self.db.storage[Ent.PRODUCT.name]

        # Supply Flow Graph
        self.supply_flow_graph = MultiDiGraph()

        # Create Nodes
        for entity_type in [supplier_data, material_data, producer_data, product_data, distributor_data, customer_data]:
            for entity in entity_type:

                entity: Supplier | Producer | Distributor | Customer | Material | Product

                # Get Node details
                node_data = entity.get_Node()

                # Create Label
                label = f"{entity.name}\n"
                for key, value in node_data.items():
                    label += f"{key}:{value}\n"
                
                # Add label (or title) to link data
                if as_label:
                    node_data['label'] = label[:-1]
                else:
                    node_data['title'] = label[:-1]

                # Add Node
                self.supply_flow_graph.add_nodes_from([(entity.name, node_data)])
        

        # Create NodeLinks
        for entity_type in [material_data, product_data, customer_data, producer_data, supplier_data]:
            for entity in entity_type:

                entity: Material | Product | Customer | Supplier

                # Get NodeLink Details
                link_data = entity.get_NodeLink()
                
                for key, value in link_data.items():

                    defined_keys = ['supplied_by', 'materials_required', 'supplies_to', 'supplies', 'produces', 'demands', 'required_for', 'supplier', 'produced_by']

                    if key in defined_keys:
                        label = key
                    else:
                        label = 'not_defined'

                    # Add label (or title) to link data
                    info = {}
                    if as_label:
                        info['label'] = label
                    else:
                        info['title'] = label

                    try:
                        for ent in value:
                            self.supply_flow_graph.add_edges_from([(entity.name, ent.name, info)])
                    except TypeError:
                        self.supply_flow_graph.add_edges_from([(entity.name, value.name, info)])
        

        return self.supply_flow_graph
                
    # Knowledge Graph
    def create_knowledge_graph(self, as_label:bool = True) -> MultiDiGraph:

        # Get all players
        supplier_data       = self.db.storage[Ent.SUPPLIER.name]
        producer_data       = self.db.storage[Ent.PRODUCER.name]
        distributor_data    = self.db.storage[Ent.DISTRIBUTOR.name]
        customer_data       = self.db.storage[Ent.CUSTOMER.name]
        material_data       = self.db.storage[Ent.MATERIAL.name]
        product_data        = self.db.storage[Ent.PRODUCT.name]

        # Generate the Transportation graph
        transport_graph  = self.transportation_graph if self.transportation_graph else self.create_transportation_graph(as_label)
        if isinstance(transport_graph, tuple):
            transport_graph, _ = transport_graph

        # Get Supply Flow Graph
        supply_flow_graph = self.supply_flow_graph if self.supply_flow_graph else self.create_supply_flow(as_label)

        # Knowledge Graph
        self.knowledge_graph = nx.compose(supply_flow_graph, transport_graph)

        # Add location details
        for entity_type in [material_data, product_data, customer_data, producer_data, supplier_data, distributor_data]:
            for entity in entity_type:

                entity: Material | Product | Customer | Supplier

                # Get Entity name and location
                name = entity.name
                loc  = entity._location

                if loc:
                    # Add label (or title) to link data
                    info = {}
                    if as_label:
                        info['label'] = 'located_at'
                    else:
                        info['title'] = 'located_at'

                    self.knowledge_graph.add_edges_from([(name, loc.name, info)])
        
        return self.knowledge_graph

# %% [markdown]
# # Step 1: Convert Raw Data to Standardize Format

# %% [markdown]
# ## Required Functions

# %%
def get_df(sheet_name: str) -> pd.DataFrame:
    return pd.read_excel('Excavator_SupplyChain_Data.xlsx', sheet_name=sheet_name)

# %%
# Convert XLXS to CSV
def xlsx_to_csv(sheet_name: str):
    get_df(sheet_name).to_csv(f'{sheet_name}.csv', index=False, header=True)
    print(f'Stored as {sheet_name}.csv')

# %%
# Dictionary to Store Nodes
NODES = {
    'locations': {},
    'product': {},
    'supplier': {},
    'producer': {},
    'distributor': {},
    'material': {}
}

DB.reset()
DB.show()
# Out:
# Entity Database

# %% [markdown]
# ## Transportation Data

# %% [markdown]
# ### Flatbed

# %%
xlsx_to_csv('FlatbedData')
df = pd.read_csv('FlatbedData.csv')
df.info()
# Out:
# Stored as FlatbedData.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2219 entries, 0 to 2218
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   source  2219 non-null   object
#  1   dest    2219 non-null   object
#  2   cost    2219 non-null   float64
#  3   time    2219 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 69.5+ KB

# %%
for fromLoc, toLoc, cost, t in df.iloc[:, :].values:

    # Add location (if not present)
    fromLoc.strip()
    if fromLoc not in NODES['locations']:
        fromLoc = fromLoc.split()[0]
        NODES['locations'][fromLoc] = Location(fromLoc)
    
    toLoc.strip()
    if toLoc not in NODES['locations']:
        toLoc = toLoc.split()[0]
        NODES['locations'][toLoc] = Location(toLoc)
    
    # Add Transportation Cost
    Transporter(NODES['locations'][fromLoc], NODES['locations'][toLoc]).price(cost).time(t)

# %% [markdown]
# ### Port to Port

# %%
xlsx_to_csv('Port-to-Port')
df = pd.read_csv('Port-to-Port.csv')
df.info()
# Out:
# Stored as Port-to-Port.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source     4500 non-null   object
#  1   dest       4500 non-null   object
#  2   cost_20ft  4500 non-null   float64
#  3   time_20ft  4500 non-null   float64
#  4   cost_40ft  4500 non-null   float64
#  5   time_40ft  4500 non-null   float64
#  6   cost_roro  4500 non-null   float64
#  7   time_roro  4496 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 281.4+ KB

# %%
for fromLoc, toLoc, cost_20ft, time_20ft, cost_40ft, time_40ft, cost_roro, time_roro in df.iloc[:, :].values:

    # Add location (if not present)
    fromLoc.strip()
    if fromLoc not in NODES['locations']:
        NODES['locations'][fromLoc] = Location(fromLoc)
    
    toLoc.strip()
    if toLoc not in NODES['locations']:
        NODES['locations'][toLoc] = Location(toLoc)
    
    # Add Transportation Cost
    Transporter(NODES['locations'][fromLoc], NODES['locations'][toLoc], name=f"{fromLoc}==>{toLoc} (20ft)").price(cost_20ft).time(time_20ft)
    Transporter(NODES['locations'][fromLoc], NODES['locations'][toLoc], name=f"{fromLoc}==>{toLoc} (40ft)").price(cost_40ft).time(time_40ft)
    Transporter(NODES['locations'][fromLoc], NODES['locations'][toLoc], name=f"{fromLoc}==>{toLoc} (roro)").price(cost_roro).time(time_roro)

# %% [markdown]
# ## Node Properties

# %% [markdown]
# ### Source Production Cost and Capacity

# %%
df = get_df("Production_Cost_Capacity")

for source_name, cost, cap in df.iloc[:, :].values:
    
    # Create Producer Node
    NODES['producer'][source_name] = Producer(source_name).at(NODES['locations'][source_name]).varCost(cost).capacity(cap)

# %% [markdown]
# ### Components

# %%
df = get_df('ComponentsQuantityAndCube')

for component, qty, length, width, height, cube, cube_per_container, weight, weight_per_container, _, water_transport, land_transport in df.iloc[:, :].values:

    # Extra Properties
    props = {
        'quantity': qty,
        'length': length,
        'width': width,
        'height': height,
        'cube': cube,
        'cube_per_container': cube_per_container,
        'weight': weight,
        'weight_per_container': weight_per_container,
        'water_transport': water_transport,
        'land_transport': land_transport
    }

    # Create Material
    NODES['material'][component] = Material(component).extra_properties(props)

# %%
comp_produced_at = {
    'CA': ['source-6', 'source-17', 'source-21'],
    'Linkage': ['source-6', 'source-21'],
    'Axles': ['source-6', 'source-17', 'source-21'],
    'Lights': ['source-6', 'source-17', 'source-21'],
    'Seat': ['source-6', 'source-17', 'source-21'],
    'Radio': ['source-6', 'source-17', 'source-21'],
    'Guard': ['source-6', 'source-17', 'source-21'],
    'Fender': ['source-6', 'source-32', 'source-21'],
    'Bucket': ['source-3', 'source-17', 'source-21'],
    'Tires': ['source-35', 'source-17', 'source-21']
}

for component in comp_produced_at:
    for source in comp_produced_at[component]:
        NODES['material'][component].by(NODES['producer'][source])

# %%
DB.show()
# Out:
# Entity Database
# 	[  1] LOCATION    N1
# 	[  2] LOCATION    B010
# 	[  3] LOCATION    B030
# 	[  4] LOCATION    B150
# 	[  5] LOCATION    B160
# 	[  6] LOCATION    B170
# 	[  7] LOCATION    B190
# 	[  8] LOCATION    B270
# 	[  9] LOCATION    B290
# 	[ 10] LOCATION    B330
# 	[ 11] LOCATION    B350
# 	[ 12] LOCATION    B370
# 	[ 13] LOCATION    B420
# 	[ 14] LOCATION    D070
# 	[ 15] LOCATION    D090
# 	[ 16] LOCATION    D100
# 	[ 17] LOCATION    D120
# 	[ 18] LOCATION    D180
# 	[ 19] LOCATION    D241
# 	[ 20] LOCATION    D260
# 	[ 21] LOCATION    D310
# 	[ 22] LOCATION    D350
# 	[ 23] LOCATION    D390
# 	[ 24] LOCATION    D420
# 	[ 25] LOCATION    D430
# 	[ 26] LOCATION    D440
# 	[ 27] LOCATION    D470
# 	[ 28] LOCATION    D480
# 	[ 29] LOCATION    D500
# 	[ 30] LOCATION    D600
# 	[ 31] LOCATION    E070
# 	[ 32] LOCATION    E130
# 	[ 33] LOCATION    E140
# 	[ 34] LOCATION    E250
# 	[ 35] LOCATION    E300
# 	[ 36] LOCATION    E30A
# 	[ 37] LOCATION    E330
# 	[ 38] LOCATION    E459
# 	[ 39] LOCATION    E480
# 	[ 40] LOCATION    E490
# 	[ 41] LOCATION    E500
# 	[ 42] LOCATION    H070
# 	[ 43] LOCATION    H160
# 	[ 44] LOCATION    H190
# 	[ 45] LOCATION    H200
# 	[ 46] LOCATION    H270
# 	[ 47] LOCATION    H330
# 	[ 48] LOCATION    H360
# 	[ 49] LOCATION    H370
# 	[ 50] LOCATION    H430
# 	[ 51] LOCATION    H510
# 	[ 52] LOCATION    N020
# 	[ 53] LOCATION    N02P
# 	[ 54] LOCATION    N030
# 	[ 55] LOCATION    N03C
# 	[ 56] LOCATION    N050
# 	[ 57] LOCATION    N070
# 	[ 58] LOCATION    N140
# 	[ 59] LOCATION    N600
# 	[ 60] LOCATION    R150
# 	[ 61] LOCATION    N2
# 	[ 62] LOCATION    B010
# 	[ 63] LOCATION    B030
# 	[ 64] LOCATION    B150
# 	[ 65] LOCATION    B160
# 	[ 66] LOCATION    B170
# 	[ 67] LOCATION    B190
# 	[ 68] LOCATION    B270
# 	[ 69] LOCATION    B290
# 	[ 70] LOCATION    B330
# 	[ 71] LOCATION    B350
# 	[ 72] LOCATION    B370
# 	[ 73] LOCATION    B420
# 	[ 74] LOCATION    D070
# 	[ 75] LOCATION    D090
# 	[ 76] LOCATION    D100
# 	[ 77] LOCATION    D120
# 	[ 78] LOCATION    D180
# 	[ 79] LOCATION    D241
# 	[ 80] LOCATION    D260
# 	[ 81] LOCATION    D310
# 	[ 82] LOCATION    D350
# 	[ 83] LOCATION    D390
# 	[ 84] LOCATION    D420
# 	[ 85] LOCATION    D430
# 	[ 86] LOCATION    D440
# 	[ 87] LOCATION    D470
# 	[ 88] LOCATION    D480
# 	[ 89] LOCATION    D500
# 	[ 90] LOCATION    D600
# 	[ 91] LOCATION    E070
# 	[ 92] LOCATION    E130
# 	[ 93] LOCATION    E140
# 	[ 94] LOCATION    E250
# 	[ 95] LOCATION    E300
# 	[ 96] LOCATION    E30A
# 	[ 97] LOCATION    E330
# 	[ 98] LOCATION    E459
# 	[ 99] LOCATION    E480
# 	[100] LOCATION    E490
# 	[101] LOCATION    E500
# 	[102] LOCATION    H070
# 	[103] LOCATION    H160
# 	[104] LOCATION    H190
# 	[105] LOCATION    H200
# 	[106] LOCATION    H270
# 	[107] LOCATION    H330
# 	[108] LOCATION    H360
# 	[109] LOCATION    H370
# 	[110] LOCATION    H430
# 	[111] LOCATION    H510
# 	[112] LOCATION    N020
# 	[113] LOCATION    N02P
# 	[114] LOCATION    N030
# 	[115] LOCATION    N03C
# 	[116] LOCATION    N050
# 	[117] LOCATION    N070
# 	[118] LOCATION    N140
# 	[119] LOCATION    N600
# 	[120] LOCATION    R150
# 	[121] LOCATION    V208
# 	[122] LOCATION    N3
# 	[123] LOCATION    B010
# 	[124] LOCATION    B030
# 	[125] LOCATION    B150
# 	[126] LOCATION    B160
# 	[127] LOCATION    B170
# 	[128] LOCATION    B190
# 	[129] LOCATION    B270
# 	[130] LOCATION    B290
# 	[131] LOCATION    B330
# 	[132] LOCATION    B350
# 	[133] LOCATION    B370
# 	[134] LOCATION    B420
# 	[135] LOCATION    D070
# 	[136] LOCATION    D090
# 	[137] LOCATION    D100
# 	[138] LOCATION    D120
# 	[139] LOCATION    D180
# 	[140] LOCATION    D241
# 	[141] LOCATION    D260
# 	[142] LOCATION    D310
# 	[143] LOCATION    D350
# 	[144] LOCATION    D390
# 	[145] LOCATION    D420
# 	[146] LOCATION    D430
# 	[147] LOCATION    D440
# 	[148] LOCATION    D470
# 	[149] LOCATION    D480
# 	[150] LOCATION    D500
# 	[151] LOCATION    D600
# 	[152] LOCATION    E070
# 	[153] LOCATION    E130
# 	[154] LOCATION    E140
# 	[155] LOCATION    E250
# 	[156] LOCATION    E300
# 	[157] LOCATION    E30A
# 	[158] LOCATION    E330
# 	[159] LOCATION    E459
# 	[160] LOCATION    E480
# 	[161] LOCATION    E490
# 	[162] LOCATION    E500
# 	[163] LOCATION    H070
# 	[164] LOCATION    H160
# 	[165] LOCATION    H190
# 	[166] LOCATION    H200
# 	[167] LOCATION    H270
# 	[168] LOCATION    H330
# 	[169] LOCATION    H360
# 	[170] LOCATION    H370
# 	[171] LOCATION    H430
# 	[172] LOCATION    H510
# 	[173] LOCATION    N020
# 	[174] LOCATION    N02P
# 	[175] LOCATION    N030
# 	[176] LOCATION    N03C
# 	[177] LOCATION    N050
# 	[178] LOCATION    N070
# 	[179] LOCATION    N140
# 	[180] LOCATION    N600
# 	[181] LOCATION    P230
# 	[182] LOCATION    R150
# 	[183] LOCATION    V208
# 	[184] LOCATION    N4
# 	[185] LOCATION    B010
# 	[186] LOCATION    B030
# 	[187] LOCATION    B150
# 	[188] LOCATION    B160
# 	[189] LOCATION    B170
# 	[190] LOCATION    B190
# 	[191] LOCATION    B270
# 	[192] LOCATION    B290
# 	[193] LOCATION    B330
# 	[194] LOCATION    B350
# 	[195] LOCATION    B370
# 	[196] LOCATION    B420
# 	[197] LOCATION    D070
# 	[198] LOCATION    D090
# 	[199] LOCATION    D100
# 	[200] LOCATION    D120
# 	[201] LOCATION    D180
# 	[202] LOCATION    D241
# 	[203] LOCATION    D260
# 	[204] LOCATION    D310
# 	[205] LOCATION    D350
# 	[206] LOCATION    D390
# 	[207] LOCATION    D420
# 	[208] LOCATION    D430
# 	[209] LOCATION    D440
# 	[210] LOCATION    D470
# 	[211] LOCATION    D480
# 	[212] LOCATION    D500
# 	[213] LOCATION    D600
# 	[214] LOCATION    E070
# 	[215] LOCATION    E130
# 	[216] LOCATION    E140
# 	[217] LOCATION    E250
# 	[218] LOCATION    E300
# 	[219] LOCATION    E30A
# 	[220] LOCATION    E330
# 	[221] LOCATION    E459
# 	[222] LOCATION    E480
# 	[223] LOCATION    E490
# 	[224] LOCATION    E500
# 	[225] LOCATION    H070
# 	[226] LOCATION    H160
# 	[227] LOCATION    H190
# 	[228] LOCATION    H200
# 	[229] LOCATION    H270
# 	[230] LOCATION    H330
# 	[231] LOCATION    H360
# 	[232] LOCATION    H370
# 	[233] LOCATION    H430
# 	[234] LOCATION    H510
# 	[235] LOCATION    N020
# 	[236] LOCATION    N02P
# 	[237] LOCATION    N030
# 	[238] LOCATION    N03C
# 	[239] LOCATION    N050
# 	[240] LOCATION    N070
# 	[241] LOCATION    N140
# 	[242] LOCATION    N600
# 	[243] LOCATION    P020
# 	[244] LOCATION    P230
# 	[245] LOCATION    P260
# 	[246] LOCATION    P280
# 	[247] LOCATION    V208
# 	[248] LOCATION    N5
# 	[249] LOCATION    B010
# 	[250] LOCATION    B030
# 	[251] LOCATION    B150
# 	[252] LOCATION    B160
# 	[253] LOCATION    B170
# 	[254] LOCATION    B190
# 	[255] LOCATION    B270
# 	[256] LOCATION    B290
# 	[257] LOCATION    B330
# 	[258] LOCATION    B350
# 	[259] LOCATION    B370
# 	[260] LOCATION    B420
# 	[261] LOCATION    D070
# 	[262] LOCATION    D090
# 	[263] LOCATION    D100
# 	[264] LOCATION    D120
# 	[265] LOCATION    D180
# 	[266] LOCATION    D241
# 	[267] LOCATION    D260
# 	[268] LOCATION    D310
# 	[269] LOCATION    D350
# 	[270] LOCATION    D390
# 	[271] LOCATION    D420
# 	[272] LOCATION    D430
# 	[273] LOCATION    D440
# 	[274] LOCATION    D470
# 	[275] LOCATION    D480
# 	[276] LOCATION    D500
# 	[277] LOCATION    D600
# 	[278] LOCATION    E070
# 	[279] LOCATION    E130
# 	[280] LOCATION    E140
# 	[281] LOCATION    E250
# 	[282] LOCATION    E300
# 	[283] LOCATION    E30A
# 	[284] LOCATION    E330
# 	[285] LOCATION    E459
# 	[286] LOCATION    E480
# 	[287] LOCATION    E490
# 	[288] LOCATION    E500
# 	[289] LOCATION    H070
# 	[290] LOCATION    H160
# 	[291] LOCATION    H190
# 	[292] LOCATION    H200
# 	[293] LOCATION    H270
# 	[294] LOCATION    H330
# 	[295] LOCATION    H360
# 	[296] LOCATION    H370
# 	[297] LOCATION    H430
# 	[298] LOCATION    H510
# 	[299] LOCATION    N020
# 	[300] LOCATION    N02P
# 	[301] LOCATION    N030
# 	[302] LOCATION    N03C
# 	[303] LOCATION    N050
# 	[304] LOCATION    N070
# 	[305] LOCATION    N140
# 	[306] LOCATION    N600
# 	[307] LOCATION    P020
# 	[308] LOCATION    P230
# 	[309] LOCATION    P280
# 	[310] LOCATION    V208
# 	[311] LOCATION    N6
# 	[312] LOCATION    B010
# 	[313] LOCATION    B030
# 	[314] LOCATION    B150
# 	[315] LOCATION    B160
# 	[316] LOCATION    B170
# 	[317] LOCATION    B190
# 	[318] LOCATION    B270
# 	[319] LOCATION    B290
# 	[320] LOCATION    B330
# 	[321] LOCATION    B350
# 	[322] LOCATION    B370
# 	[323] LOCATION    B420
# 	[324] LOCATION    D070
# 	[325] LOCATION    D090
# 	[326] LOCATION    D100
# 	[327] LOCATION    D120
# 	[328] LOCATION    D180
# 	[329] LOCATION    D241
# 	[330] LOCATION    D260
# 	[331] LOCATION    D310
# 	[332] LOCATION    D350
# 	[333] LOCATION    D390
# 	[334] LOCATION    D420
# 	[335] LOCATION    D430
# 	[336] LOCATION    D440
# 	[337] LOCATION    D470
# 	[338] LOCATION    D480
# 	[339] LOCATION    D500
# 	[340] LOCATION    D600
# 	[341] LOCATION    E070
# 	[342] LOCATION    E130
# 	[343] LOCATION    E140
# 	[344] LOCATION    E250
# 	[345] LOCATION    E300
# 	[346] LOCATION    E30A
# 	[347] LOCATION    E330
# 	[348] LOCATION    E459
# 	[349] LOCATION    E480
# 	[350] LOCATION    E490
# 	[351] LOCATION    E500
# 	[352] LOCATION    H070
# 	[353] LOCATION    H160
# 	[354] LOCATION    H190
# 	[355] LOCATION    H200
# 	[356] LOCATION    H270
# 	[357] LOCATION    H330
# 	[358] LOCATION    H360
# 	[359] LOCATION    H370
# 	[360] LOCATION    H430
# 	[361] LOCATION    H510
# 	[362] LOCATION    N020
# 	[363] LOCATION    N02P
# 	[364] LOCATION    N030
# 	[365] LOCATION    N03C
# 	[366] LOCATION    N050
# 	[367] LOCATION    N070
# 	[368] LOCATION    N140
# 	[369] LOCATION    N600
# 	[370] LOCATION    P020
# 	[371] LOCATION    N8
# 	[372] LOCATION    H140
# 	[373] LOCATION    N9
# 	[374] LOCATION    P020
# 	[375] LOCATION    P050
# 	[376] LOCATION    P120
# 	[377] LOCATION    P210
# 	[378] LOCATION    P230
# 	[379] LOCATION    P260
# 	[380] LOCATION    P280
# 	[381] LOCATION    P340
# 	[382] LOCATION    P370
# 	[383] LOCATION    P380
# 	[384] LOCATION    N10
# 	[385] LOCATION    P020
# 	[386] LOCATION    P050
# 	[387] LOCATION    P120
# 	[388] LOCATION    P210
# 	[389] LOCATION    P230
# 	[390] LOCATION    P260
# 	[391] LOCATION    P280
# 	[392] LOCATION    P340
# 	[393] LOCATION    P370
# 	[394] LOCATION    P380
# 	[395] LOCATION    S1
# 	[396] LOCATION    P160
# 	[397] LOCATION    P310
# 	[398] LOCATION    P420
# 	[399] LOCATION    R160
# 	[400] LOCATION    R350
# 	[401] LOCATION    R400
# 	[402] LOCATION    R460
# 	[403] LOCATION    S2
# 	[404] LOCATION    R160
# 	[405] LOCATION    R350
# 	[406] LOCATION    R400
# 	[407] LOCATION    U060
# 	[408] LOCATION    U170
# 	[409] LOCATION    S3
# 	[410] LOCATION    R050
# 	[411] LOCATION    R100
# 	[412] LOCATION    R180
# 	[413] LOCATION    R200
# 	[414] LOCATION    U060
# 	[415] LOCATION    U170
# 	[416] LOCATION    S4
# 	[417] LOCATION    R050
# 	[418] LOCATION    R100
# 	[419] LOCATION    R120
# 	[420] LOCATION    R180
# 	[421] LOCATION    R200
# 	[422] LOCATION    U060
# 	[423] LOCATION    U170
# 	[424] LOCATION    S5
# 	[425] LOCATION    R050
# 	[426] LOCATION    R100
# 	[427] LOCATION    R120
# 	[428] LOCATION    S6
# 	[429] LOCATION    R070
# 	[430] LOCATION    R080
# 	[431] LOCATION    R095
# 	[432] LOCATION    R180
# 	[433] LOCATION    R440
# 	[434] LOCATION    R460
# 	[435] LOCATION    S7
# 	[436] LOCATION    P050
# 	[437] LOCATION    P120
# 	[438] LOCATION    P210
# 	[439] LOCATION    P340
# 	[440] LOCATION    P370
# 	[441] LOCATION    P380
# 	[442] LOCATION    R070
# 	[443] LOCATION    R080
# 	[444] LOCATION    R095
# 	[445] LOCATION    R400
# 	[446] LOCATION    R440
# 	[447] LOCATION    R460
# 	[448] LOCATION    S8
# 	[449] LOCATION    R100
# 	[450] LOCATION    R120
# 	[451] LOCATION    R180
# 	[452] LOCATION    R200
# 	[453] LOCATION    R350
# 	[454] LOCATION    R400
# 	[455] LOCATION    R440
# 	[456] LOCATION    R460
# 	[457] LOCATION    U060
# 	[458] LOCATION    U170
# 	[459] LOCATION    E1
# 	[460] LOCATION    K310
# 	[461] LOCATION    L010
# 	[462] LOCATION    L030
# 	[463] LOCATION    L040
# 	[464] LOCATION    L080
# 	[465] LOCATION    L100
# 	[466] LOCATION    L110
# 	[467] LOCATION    L240
# 	[468] LOCATION    L24A
# 	[469] LOCATION    L310
# 	[470] LOCATION    L390
# 	[471] LOCATION    L400
# 	[472] LOCATION    M030
# 	[473] LOCATION    M040
# 	[474] LOCATION    M180
# 	[475] LOCATION    M450
# 	[476] LOCATION    M512
# 	[477] LOCATION    M530
# 	[478] LOCATION    V21A
# 	[479] LOCATION    V21D
# 	[480] LOCATION    V351
# 	[481] LOCATION    X080
# 	[482] LOCATION    X150
# 	[483] LOCATION    X171
# 	[484] LOCATION    X190
# 	[485] LOCATION    X191
# 	[486] LOCATION    X260
# 	[487] LOCATION    X320
# 	[488] LOCATION    X350
# 	[489] LOCATION    X355
# 	[490] LOCATION    X490
# 	[491] LOCATION    E2
# 	[492] LOCATION    J122
# 	[493] LOCATION    K310
# 	[494] LOCATION    L010
# 	[495] LOCATION    L030
# 	[496] LOCATION    L040
# 	[497] LOCATION    L080
# 	[498] LOCATION    L100
# 	[499] LOCATION    L110
# 	[500] LOCATION    L240
# 	[501] LOCATION    L24A
# 	[502] LOCATION    L310
# 	[503] LOCATION    L390
# 	[504] LOCATION    L400
# 	[505] LOCATION    M030
# 	[506] LOCATION    M040
# 	[507] LOCATION    M180
# 	[508] LOCATION    M450
# 	[509] LOCATION    M512
# 	[510] LOCATION    M530
# 	[511] LOCATION    V21A
# 	[512] LOCATION    V21D
# 	[513] LOCATION    V262
# 	[514] LOCATION    V27E
# 	[515] LOCATION    V27F
# 	[516] LOCATION    V27U
# 	[517] LOCATION    V351
# 	[518] LOCATION    X080
# 	[519] LOCATION    X150
# 	[520] LOCATION    X171
# 	[521] LOCATION    X190
# 	[522] LOCATION    X191
# 	[523] LOCATION    X320
# 	[524] LOCATION    X350
# 	[525] LOCATION    X355
# 	[526] LOCATION    X490
# 	[527] LOCATION    E3
# 	[528] LOCATION    K310
# 	[529] LOCATION    L010
# 	[530] LOCATION    L030
# 	[531] LOCATION    L040
# 	[532] LOCATION    L080
# 	[533] LOCATION    L100
# 	[534] LOCATION    L110
# 	[535] LOCATION    L240
# 	[536] LOCATION    L24A
# 	[537] LOCATION    L310
# 	[538] LOCATION    L390
# 	[539] LOCATION    L400
# 	[540] LOCATION    M030
# 	[541] LOCATION    M040
# 	[542] LOCATION    M180
# 	[543] LOCATION    M512
# 	[544] LOCATION    M530
# 	[545] LOCATION    V21A
# 	[546] LOCATION    V21D
# 	[547] LOCATION    X080
# 	[548] LOCATION    X150
# 	[549] LOCATION    X171
# 	[550] LOCATION    X190
# 	[551] LOCATION    X191
# 	[552] LOCATION    X320
# 	[553] LOCATION    X350
# 	[554] LOCATION    X355
# 	[555] LOCATION    X490
# 	[556] LOCATION    E4
# 	[557] LOCATION    K310
# 	[558] LOCATION    M610
# 	[559] LOCATION    V21A
# 	[560] LOCATION    V21D
# 	[561] LOCATION    E5
# 	[562] LOCATION    K310
# 	[563] LOCATION    L010
# 	[564] LOCATION    L030
# 	[565] LOCATION    L040
# 	[566] LOCATION    L080
# 	[567] LOCATION    L100
# 	[568] LOCATION    L110
# 	[569] LOCATION    L240
# 	[570] LOCATION    L24A
# 	[571] LOCATION    L310
# 	[572] LOCATION    L390
# 	[573] LOCATION    L400
# 	[574] LOCATION    M030
# 	[575] LOCATION    M040
# 	[576] LOCATION    M180
# 	[577] LOCATION    M512
# 	[578] LOCATION    M530
# 	[579] LOCATION    X080
# 	[580] LOCATION    X150
# 	[581] LOCATION    X171
# 	[582] LOCATION    X190
# 	[583] LOCATION    X191
# 	[584] LOCATION    X260
# 	[585] LOCATION    X320
# 	[586] LOCATION    X350
# 	[587] LOCATION    X355
# 	[588] LOCATION    X490
# 	[589] LOCATION    E6
# 	[590] LOCATION    K666
# 	[591] LOCATION    L010
# 	[592] LOCATION    L030
# 	[593] LOCATION    L040
# 	[594] LOCATION    L080
# 	[595] LOCATION    L100
# 	[596] LOCATION    L110
# 	[597] LOCATION    L240
# 	[598] LOCATION    L24A
# 	[599] LOCATION    L310
# 	[600] LOCATION    L390
# 	[601] LOCATION    L400
# 	[602] LOCATION    M030
# 	[603] LOCATION    M040
# 	[604] LOCATION    M080
# 	[605] LOCATION    M180
# 	[606] LOCATION    M400
# 	[607] LOCATION    M450
# 	[608] LOCATION    M512
# 	[609] LOCATION    M530
# 	[610] LOCATION    M620
# 	[611] LOCATION    Q160
# 	[612] LOCATION    X080
# 	[613] LOCATION    X150
# 	[614] LOCATION    X171
# 	[615] LOCATION    X190
# 	[616] LOCATION    X191
# 	[617] LOCATION    X320
# 	[618] LOCATION    X350
# 	[619] LOCATION    X355
# 	[620] LOCATION    X490
# 	[621] LOCATION    X540
# 	[622] LOCATION    E7
# 	[623] LOCATION    L010
# 	[624] LOCATION    L030
# 	[625] LOCATION    L040
# 	[626] LOCATION    L080
# 	[627] LOCATION    L100
# 	[628] LOCATION    L110
# 	[629] LOCATION    L240
# 	[630] LOCATION    L24A
# 	[631] LOCATION    L310
# 	[632] LOCATION    L390
# 	[633] LOCATION    L400
# 	[634] LOCATION    M030
# 	[635] LOCATION    M040
# 	[636] LOCATION    M080
# 	[637] LOCATION    M180
# 	[638] LOCATION    M450
# 	[639] LOCATION    M512
# 	[640] LOCATION    M530
# 	[641] LOCATION    Q160
# 	[642] LOCATION    V255
# 	[643] LOCATION    V351
# 	[644] LOCATION    V362
# 	[645] LOCATION    V363
# 	[646] LOCATION    X080
# 	[647] LOCATION    X150
# 	[648] LOCATION    X171
# 	[649] LOCATION    X190
# 	[650] LOCATION    X191
# 	[651] LOCATION    X320
# 	[652] LOCATION    X350
# 	[653] LOCATION    X355
# 	[654] LOCATION    X490
# 	[655] LOCATION    E10
# 	[656] LOCATION    K310
# 	[657] LOCATION    K610
# 	[658] LOCATION    K620
# 	[659] LOCATION    K625
# 	[660] LOCATION    K630
# 	[661] LOCATION    K645
# 	[662] LOCATION    K666
# 	[663] LOCATION    K671
# 	[664] LOCATION    L010
# 	[665] LOCATION    L030
# 	[666] LOCATION    L040
# 	[667] LOCATION    L080
# 	[668] LOCATION    L100
# 	[669] LOCATION    L110
# 	[670] LOCATION    L240
# 	[671] LOCATION    L24A
# 	[672] LOCATION    L310
# 	[673] LOCATION    L390
# 	[674] LOCATION    L400
# 	[675] LOCATION    M030
# 	[676] LOCATION    M040
# 	[677] LOCATION    M080
# 	[678] LOCATION    M180
# 	[679] LOCATION    M400
# 	[680] LOCATION    M450
# 	[681] LOCATION    M512
# 	[682] LOCATION    M530
# 	[683] LOCATION    Q160
# 	[684] LOCATION    V255
# 	[685] LOCATION    V351
# 	[686] LOCATION    V362
# 	[687] LOCATION    V363
# 	[688] LOCATION    X080
# 	[689] LOCATION    X150
# 	[690] LOCATION    X171
# 	[691] LOCATION    X190
# 	[692] LOCATION    X191
# 	[693] LOCATION    X320
# 	[694] LOCATION    X350
# 	[695] LOCATION    X355
# 	[696] LOCATION    X490
# 	[697] LOCATION    M1
# 	[698] LOCATION    K491
# 	[699] LOCATION    K666
# 	[700] LOCATION    M080
# 	[701] LOCATION    M400
# 	[702] LOCATION    M450
# 	[703] LOCATION    M620
# 	[704] LOCATION    Q160
# 	[705] LOCATION    Q630
# 	[706] LOCATION    X540
# 	[707] LOCATION    M2
# 	[708] LOCATION    K491
# 	[709] LOCATION    K666
# 	[710] LOCATION    M620
# 	[711] LOCATION    Q300
# 	[712] LOCATION    Q301
# 	[713] LOCATION    Q302
# 	[714] LOCATION    Q303
# 	[715] LOCATION    Q305
# 	[716] LOCATION    Q630
# 	[717] LOCATION    V362
# 	[718] LOCATION    X540
# 	[719] LOCATION    M3
# 	[720] LOCATION    K210
# 	[721] LOCATION    K491
# 	[722] LOCATION    K671
# 	[723] LOCATION    Q630
# 	[724] LOCATION    V21A
# 	[725] LOCATION    V21D
# 	[726] LOCATION    V255
# 	[727] LOCATION    V27E
# 	[728] LOCATION    V27F
# 	[729] LOCATION    V27U
# 	[730] LOCATION    V362
# 	[731] LOCATION    V363
# 	[732] LOCATION    M4
# 	[733] LOCATION    K610
# 	[734] LOCATION    K620
# 	[735] LOCATION    K630
# 	[736] LOCATION    K645
# 	[737] LOCATION    M5
# 	[738] LOCATION    K02A
# 	[739] LOCATION    K030
# 	[740] LOCATION    M6
# 	[741] LOCATION    K02A
# 	[742] LOCATION    K030
# 	[743] LOCATION    M7
# 	[744] LOCATION    K610
# 	[745] LOCATION    K620
# 	[746] LOCATION    K630
# 	[747] LOCATION    K645
# 	[748] LOCATION    M8
# 	[749] LOCATION    K30F
# 	[750] LOCATION    K625
# 	[751] LOCATION    M9
# 	[752] LOCATION    K30F
# 	[753] LOCATION    K625
# 	[754] LOCATION    M10
# 	[755] LOCATION    K30F
# 	[756] LOCATION    K625
# 	[757] LOCATION    M400
# 	[758] LOCATION    M620
# 	[759] LOCATION    M11
# 	[760] LOCATION    K610
# 	[761] LOCATION    K620
# 	[762] LOCATION    K630
# 	[763] LOCATION    K645
# 	[764] LOCATION    M12
# 	[765] LOCATION    K30F
# 	[766] LOCATION    K625
# 	[767] LOCATION    M13
# 	[768] LOCATION    K02A
# 	[769] LOCATION    K030
# 	[770] LOCATION    K310
# 	[771] LOCATION    K1
# 	[772] LOCATION    J09T
# 	[773] LOCATION    J122
# 	[774] LOCATION    J25D
# 	[775] LOCATION    K210
# 	[776] LOCATION    K671
# 	[777] LOCATION    V362
# 	[778] LOCATION    V363
# 	[779] LOCATION    K2
# 	[780] LOCATION    K600
# 	[781] LOCATION    K3
# 	[782] LOCATION    J122
# 	[783] LOCATION    J25D
# 	[784] LOCATION    K210
# 	[785] LOCATION    K625
# 	[786] LOCATION    K671
# 	[787] LOCATION    V362
# 	[788] LOCATION    V363
# 	[789] LOCATION    K4
# 	[790] LOCATION    J09T
# 	[791] LOCATION    K5
# 	[792] LOCATION    J122
# 	[793] LOCATION    J25D
# 	[794] LOCATION    K210
# 	[795] LOCATION    K625
# 	[796] LOCATION    K671
# 	[797] LOCATION    V362
# 	[798] LOCATION    V363
# 	[799] LOCATION    A1
# 	[800] LOCATION    W220
# 	[801] LOCATION    W230
# 	[802] LOCATION    W310
# 	[803] LOCATION    W611
# 	[804] LOCATION    W670
# 	[805] LOCATION    W720
# 	[806] LOCATION    V237
# 	[807] LOCATION    A2
# 	[808] LOCATION    J080
# 	[809] LOCATION    W220
# 	[810] LOCATION    W230
# 	[811] LOCATION    W310
# 	[812] LOCATION    W611
# 	[813] LOCATION    W670
# 	[814] LOCATION    W720
# 	[815] LOCATION    V237
# 	[816] LOCATION    A3
# 	[817] LOCATION    J010
# 	[818] LOCATION    J016
# 	[819] LOCATION    J018
# 	[820] LOCATION    J021
# 	[821] LOCATION    J022
# 	[822] LOCATION    J080
# 	[823] LOCATION    J0AA
# 	[824] LOCATION    J121
# 	[825] LOCATION    J251
# 	[826] LOCATION    J440
# 	[827] LOCATION    J490
# 	[828] LOCATION    J540
# 	[829] LOCATION    J560
# 	[830] LOCATION    V234
# 	[831] LOCATION    V266
# 	[832] LOCATION    A4
# 	[833] LOCATION    J010
# 	[834] LOCATION    J016
# 	[835] LOCATION    J018
# 	[836] LOCATION    J021
# 	[837] LOCATION    J022
# 	[838] LOCATION    J039
# 	[839] LOCATION    J040
# 	[840] LOCATION    J050
# 	[841] LOCATION    J121
# 	[842] LOCATION    J251
# 	[843] LOCATION    J440
# 	[844] LOCATION    J490
# 	[845] LOCATION    J520
# 	[846] LOCATION    J570
# 	[847] LOCATION    V266
# 	[848] LOCATION    A5
# 	[849] LOCATION    J039
# 	[850] LOCATION    J040
# 	[851] LOCATION    J050
# 	[852] LOCATION    J210
# 	[853] LOCATION    J280
# 	[854] LOCATION    J320
# 	[855] LOCATION    J520
# 	[856] LOCATION    J570
# 	[857] LOCATION    A6
# 	[858] LOCATION    J065
# 	[859] LOCATION    J090
# 	[860] LOCATION    J093
# 	[861] LOCATION    J09R
# 	[862] LOCATION    J09T
# 	[863] LOCATION    J250
# 	[864] LOCATION    J251
# 	[865] LOCATION    J25C
# 	[866] LOCATION    J25D
# 	[867] LOCATION    J300
# 	[868] LOCATION    A7
# 	[869] LOCATION    J065
# 	[870] LOCATION    J090
# 	[871] LOCATION    J093
# 	[872] LOCATION    J09R
# 	[873] LOCATION    J09T
# 	[874] LOCATION    J250
# 	[875] LOCATION    J251
# 	[876] LOCATION    J25C
# 	[877] LOCATION    J25D
# 	[878] LOCATION    A8
# 	[879] LOCATION    J010
# 	[880] LOCATION    J016
# 	[881] LOCATION    J018
# 	[882] LOCATION    J021
# 	[883] LOCATION    J022
# 	[884] LOCATION    J039
# 	[885] LOCATION    J040
# 	[886] LOCATION    J050
# 	[887] LOCATION    J121
# 	[888] LOCATION    J251
# 	[889] LOCATION    J440
# 	[890] LOCATION    J490
# 	[891] LOCATION    J520
# 	[892] LOCATION    J570
# 	[893] LOCATION    A9
# 	[894] LOCATION    J010
# 	[895] LOCATION    J016
# 	[896] LOCATION    J018
# 	[897] LOCATION    J021
# 	[898] LOCATION    J022
# 	[899] LOCATION    J039
# 	[900] LOCATION    J040
# 	[901] LOCATION    J050
# 	[902] LOCATION    J121
# 	[903] LOCATION    J251
# 	[904] LOCATION    J440
# 	[905] LOCATION    J490
# 	[906] LOCATION    J520
# 	[907] LOCATION    J570
# 	[908] LOCATION    A12
# 	[909] LOCATION    W220
# 	[910] LOCATION    W230
# 	[911] LOCATION    W310
# 	[912] LOCATION    W611
# 	[913] LOCATION    W670
# 	[914] LOCATION    W720
# 	[915] LOCATION    A14
# 	[916] LOCATION    J370
# 	[917] LOCATION    Z1
# 	[918] LOCATION    T030
# 	[919] LOCATION    T040
# 	[920] LOCATION    T120
# 	[921] LOCATION    Z2
# 	[922] LOCATION    T010
# 	[923] LOCATION    T030
# 	[924] LOCATION    T120
# 	[925] LOCATION    Z3
# 	[926] LOCATION    T010
# 	[927] LOCATION    T070
# 	[928] LOCATION    T120
# 	[929] LOCATION    Z4
# 	[930] LOCATION    T210
# 	[931] LOCATION    Z5
# 	[932] LOCATION    T010
# 	[933] LOCATION    T070
# 	[934] LOCATION    T080
# 	[935] LOCATION    Z7
# 	[936] LOCATION    T010
# 	[937] LOCATION    T070
# 	[938] LOCATION    T080
# 	[939] LOCATION    source-1
# 	[940] LOCATION    B010
# 	[941] LOCATION    B190
# 	[942] LOCATION    B030
# 	[943] LOCATION    B150
# 	[944] LOCATION    B160
# 	[945] LOCATION    B170
# 	[946] LOCATION    B270
# 	[947] LOCATION    B290
# 	[948] LOCATION    B330
# 	[949] LOCATION    B350
# 	[950] LOCATION    B370
# 	[951] LOCATION    B420
# 	[952] LOCATION    D070
# 	[953] LOCATION    D090
# 	[954] LOCATION    D100
# 	[955] LOCATION    D120
# 	[956] LOCATION    D180
# 	[957] LOCATION    D241
# 	[958] LOCATION    D260
# 	[959] LOCATION    D310
# 	[960] LOCATION    D350
# 	[961] LOCATION    D390
# 	[962] LOCATION    D420
# 	[963] LOCATION    D430
# 	[964] LOCATION    D440
# 	[965] LOCATION    D470
# 	[966] LOCATION    D480
# 	[967] LOCATION    D500
# 	[968] LOCATION    D600
# 	[969] LOCATION    E070
# 	[970] LOCATION    E130
# 	[971] LOCATION    E140
# 	[972] LOCATION    E250
# 	[973] LOCATION    E300
# 	[974] LOCATION    E30A
# 	[975] LOCATION    E330
# 	[976] LOCATION    E459
# 	[977] LOCATION    E480
# 	[978] LOCATION    E490
# 	[979] LOCATION    E500
# 	[980] LOCATION    H070
# 	[981] LOCATION    H160
# 	[982] LOCATION    H190
# 	[983] LOCATION    H200
# 	[984] LOCATION    H270
# 	[985] LOCATION    H330
# 	[986] LOCATION    H360
# 	[987] LOCATION    H370
# 	[988] LOCATION    H430
# 	[989] LOCATION    H510
# 	[990] LOCATION    N020
# 	[991] LOCATION    N02P
# 	[992] LOCATION    N030
# 	[993] LOCATION    N03C
# 	[994] LOCATION    N050
# 	[995] LOCATION    N070
# 	[996] LOCATION    N140
# 	[997] LOCATION    N600
# 	[998] LOCATION    P020
# 	[999] LOCATION    P280
# 	[1000] LOCATION    source-2
# 	[1001] LOCATION    source-3
# 	[1002] LOCATION    source-4
# 	[1003] LOCATION    source-5
# 	[1004] LOCATION    source-6
# 	[1005] LOCATION    source-7
# 	[1006] LOCATION    source-8
# 	[1007] LOCATION    source-10
# 	[1008] LOCATION    source-11
# 	[1009] LOCATION    B010
# 	[1010] LOCATION    B190
# 	[1011] LOCATION    B030
# 	[1012] LOCATION    B150
# 	[1013] LOCATION    B160
# 	[1014] LOCATION    B170
# 	[1015] LOCATION    B270
# 	[1016] LOCATION    B290
# 	[1017] LOCATION    B330
# 	[1018] LOCATION    B350
# 	[1019] LOCATION    B370
# 	[1020] LOCATION    B420
# 	[1021] LOCATION    D070
# 	[1022] LOCATION    D090
# 	[1023] LOCATION    D100
# 	[1024] LOCATION    D120
# 	[1025] LOCATION    D180
# 	[1026] LOCATION    D241
# 	[1027] LOCATION    D260
# 	[1028] LOCATION    D310
# 	[1029] LOCATION    D350
# 	[1030] LOCATION    D390
# 	[1031] LOCATION    D420
# 	[1032] LOCATION    D430
# 	[1033] LOCATION    D440
# 	[1034] LOCATION    D470
# 	[1035] LOCATION    D480
# 	[1036] LOCATION    D500
# 	[1037] LOCATION    D600
# 	[1038] LOCATION    E070
# 	[1039] LOCATION    E130
# 	[1040] LOCATION    E140
# 	[1041] LOCATION    E250
# 	[1042] LOCATION    E300
# 	[1043] LOCATION    E30A
# 	[1044] LOCATION    E330
# 	[1045] LOCATION    E459
# 	[1046] LOCATION    E480
# 	[1047] LOCATION    E490
# 	[1048] LOCATION    E500
# 	[1049] LOCATION    H070
# 	[1050] LOCATION    H160
# 	[1051] LOCATION    H190
# 	[1052] LOCATION    H200
# 	[1053] LOCATION    H270
# 	[1054] LOCATION    H330
# 	[1055] LOCATION    H360
# 	[1056] LOCATION    H370
# 	[1057] LOCATION    H430
# 	[1058] LOCATION    H510
# 	[1059] LOCATION    N020
# 	[1060] LOCATION    N02P
# 	[1061] LOCATION    N030
# 	[1062] LOCATION    N03C
# 	[1063] LOCATION    N050
# 	[1064] LOCATION    N070
# 	[1065] LOCATION    N140
# 	[1066] LOCATION    N600
# 	[1067] LOCATION    P020
# 	[1068] LOCATION    P230
# 	[1069] LOCATION    P280
# 	[1070] LOCATION    V208
# 	[1071] LOCATION    B010
# 	[1072] LOCATION    B190
# 	[1073] LOCATION    B030
# 	[1074] LOCATION    B150
# 	[1075] LOCATION    B160
# 	[1076] LOCATION    B170
# 	[1077] LOCATION    B270
# 	[1078] LOCATION    B290
# 	[1079] LOCATION    B330
# 	[1080] LOCATION    B350
# 	[1081] LOCATION    B370
# 	[1082] LOCATION    B420
# 	[1083] LOCATION    D070
# 	[1084] LOCATION    D090
# 	[1085] LOCATION    D100
# 	[1086] LOCATION    D120
# 	[1087] LOCATION    D180
# 	[1088] LOCATION    D241
# 	[1089] LOCATION    D260
# 	[1090] LOCATION    D310
# 	[1091] LOCATION    D350
# 	[1092] LOCATION    D390
# 	[1093] LOCATION    D420
# 	[1094] LOCATION    D430
# 	[1095] LOCATION    D440
# 	[1096] LOCATION    D470
# 	[1097] LOCATION    D480
# 	[1098] LOCATION    D500
# 	[1099] LOCATION    D600
# 	[1100] LOCATION    E070
# 	[1101] LOCATION    E130
# 	[1102] LOCATION    E140
# 	[1103] LOCATION    E250
# 	[1104] LOCATION    E300
# 	[1105] LOCATION    E30A
# 	[1106] LOCATION    E330
# 	[1107] LOCATION    E459
# 	[1108] LOCATION    E480
# 	[1109] LOCATION    E490
# 	[1110] LOCATION    E500
# 	[1111] LOCATION    H070
# 	[1112] LOCATION    H160
# 	[1113] LOCATION    H190
# 	[1114] LOCATION    H200
# 	[1115] LOCATION    H270
# 	[1116] LOCATION    H330
# 	[1117] LOCATION    H360
# 	[1118] LOCATION    H370
# 	[1119] LOCATION    H430
# 	[1120] LOCATION    H510
# 	[1121] LOCATION    N020
# 	[1122] LOCATION    N02P
# 	[1123] LOCATION    N030
# 	[1124] LOCATION    N03C
# 	[1125] LOCATION    N050
# 	[1126] LOCATION    N070
# 	[1127] LOCATION    N140
# 	[1128] LOCATION    N600
# 	[1129] LOCATION    P020
# 	[1130] LOCATION    P230
# 	[1131] LOCATION    P260
# 	[1132] LOCATION    P280
# 	[1133] LOCATION    R150
# 	[1134] LOCATION    B010
# 	[1135] LOCATION    B190
# 	[1136] LOCATION    B030
# 	[1137] LOCATION    B150
# 	[1138] LOCATION    B160
# 	[1139] LOCATION    B170
# 	[1140] LOCATION    B270
# 	[1141] LOCATION    B290
# 	[1142] LOCATION    B330
# 	[1143] LOCATION    B350
# 	[1144] LOCATION    B370
# 	[1145] LOCATION    B420
# 	[1146] LOCATION    D070
# 	[1147] LOCATION    D090
# 	[1148] LOCATION    D100
# 	[1149] LOCATION    D120
# 	[1150] LOCATION    D180
# 	[1151] LOCATION    D241
# 	[1152] LOCATION    D260
# 	[1153] LOCATION    D310
# 	[1154] LOCATION    D350
# 	[1155] LOCATION    D390
# 	[1156] LOCATION    D420
# 	[1157] LOCATION    D430
# 	[1158] LOCATION    D440
# 	[1159] LOCATION    D470
# 	[1160] LOCATION    D480
# 	[1161] LOCATION    D500
# 	[1162] LOCATION    D600
# 	[1163] LOCATION    E070
# 	[1164] LOCATION    E130
# 	[1165] LOCATION    E140
# 	[1166] LOCATION    E250
# 	[1167] LOCATION    E300
# 	[1168] LOCATION    E30A
# 	[1169] LOCATION    E330
# 	[1170] LOCATION    E459
# 	[1171] LOCATION    E480
# 	[1172] LOCATION    E490
# 	[1173] LOCATION    E500
# 	[1174] LOCATION    H070
# 	[1175] LOCATION    H160
# 	[1176] LOCATION    H190
# 	[1177] LOCATION    H200
# 	[1178] LOCATION    H270
# 	[1179] LOCATION    H330
# 	[1180] LOCATION    H360
# 	[1181] LOCATION    H370
# 	[1182] LOCATION    H430
# 	[1183] LOCATION    H510
# 	[1184] LOCATION    N020
# 	[1185] LOCATION    N02P
# 	[1186] LOCATION    N030
# 	[1187] LOCATION    N03C
# 	[1188] LOCATION    N050
# 	[1189] LOCATION    N070
# 	[1190] LOCATION    N140
# 	[1191] LOCATION    N600
# 	[1192] LOCATION    P020
# 	[1193] LOCATION    P230
# 	[1194] LOCATION    P260
# 	[1195] LOCATION    P280
# 	[1196] LOCATION    P380
# 	[1197] LOCATION    R150
# 	[1198] LOCATION    V208
# 	[1199] LOCATION    B010
# 	[1200] LOCATION    B190
# 	[1201] LOCATION    B030
# 	[1202] LOCATION    B150
# 	[1203] LOCATION    B160
# 	[1204] LOCATION    B170
# 	[1205] LOCATION    B270
# 	[1206] LOCATION    B290
# 	[1207] LOCATION    B330
# 	[1208] LOCATION    B350
# 	[1209] LOCATION    B370
# 	[1210] LOCATION    B420
# 	[1211] LOCATION    D070
# 	[1212] LOCATION    D090
# 	[1213] LOCATION    D100
# 	[1214] LOCATION    D120
# 	[1215] LOCATION    D180
# 	[1216] LOCATION    D241
# 	[1217] LOCATION    D260
# 	[1218] LOCATION    D310
# 	[1219] LOCATION    D350
# 	[1220] LOCATION    D390
# 	[1221] LOCATION    D420
# 	[1222] LOCATION    D430
# 	[1223] LOCATION    D440
# 	[1224] LOCATION    D470
# 	[1225] LOCATION    D480
# 	[1226] LOCATION    D500
# 	[1227] LOCATION    D600
# 	[1228] LOCATION    E070
# 	[1229] LOCATION    E130
# 	[1230] LOCATION    E140
# 	[1231] LOCATION    E250
# 	[1232] LOCATION    E300
# 	[1233] LOCATION    E30A
# 	[1234] LOCATION    E330
# 	[1235] LOCATION    E459
# 	[1236] LOCATION    E480
# 	[1237] LOCATION    E490
# 	[1238] LOCATION    E500
# 	[1239] LOCATION    H070
# 	[1240] LOCATION    H160
# 	[1241] LOCATION    H190
# 	[1242] LOCATION    H200
# 	[1243] LOCATION    H270
# 	[1244] LOCATION    H330
# 	[1245] LOCATION    H360
# 	[1246] LOCATION    H370
# 	[1247] LOCATION    H430
# 	[1248] LOCATION    H510
# 	[1249] LOCATION    N020
# 	[1250] LOCATION    N02P
# 	[1251] LOCATION    N030
# 	[1252] LOCATION    N03C
# 	[1253] LOCATION    N050
# 	[1254] LOCATION    N070
# 	[1255] LOCATION    N140
# 	[1256] LOCATION    N600
# 	[1257] LOCATION    P020
# 	[1258] LOCATION    P230
# 	[1259] LOCATION    P260
# 	[1260] LOCATION    P280
# 	[1261] LOCATION    R150
# 	[1262] LOCATION    B010
# 	[1263] LOCATION    B190
# 	[1264] LOCATION    B030
# 	[1265] LOCATION    B150
# 	[1266] LOCATION    B160
# 	[1267] LOCATION    B170
# 	[1268] LOCATION    B270
# 	[1269] LOCATION    B290
# 	[1270] LOCATION    B330
# 	[1271] LOCATION    B350
# 	[1272] LOCATION    B370
# 	[1273] LOCATION    B420
# 	[1274] LOCATION    D070
# 	[1275] LOCATION    D090
# 	[1276] LOCATION    D100
# 	[1277] LOCATION    D120
# 	[1278] LOCATION    D180
# 	[1279] LOCATION    D241
# 	[1280] LOCATION    D260
# 	[1281] LOCATION    D310
# 	[1282] LOCATION    D350
# 	[1283] LOCATION    D390
# 	[1284] LOCATION    D420
# 	[1285] LOCATION    D430
# 	[1286] LOCATION    D440
# 	[1287] LOCATION    D470
# 	[1288] LOCATION    D480
# 	[1289] LOCATION    D500
# 	[1290] LOCATION    D600
# 	[1291] LOCATION    E070
# 	[1292] LOCATION    E130
# 	[1293] LOCATION    E140
# 	[1294] LOCATION    E250
# 	[1295] LOCATION    E300
# 	[1296] LOCATION    E30A
# 	[1297] LOCATION    E330
# 	[1298] LOCATION    E459
# 	[1299] LOCATION    E480
# 	[1300] LOCATION    E490
# 	[1301] LOCATION    E500
# 	[1302] LOCATION    H070
# 	[1303] LOCATION    H160
# 	[1304] LOCATION    H190
# 	[1305] LOCATION    H200
# 	[1306] LOCATION    H270
# 	[1307] LOCATION    H330
# 	[1308] LOCATION    H360
# 	[1309] LOCATION    H370
# 	[1310] LOCATION    H430
# 	[1311] LOCATION    H510
# 	[1312] LOCATION    N020
# 	[1313] LOCATION    N02P
# 	[1314] LOCATION    N030
# 	[1315] LOCATION    N03C
# 	[1316] LOCATION    N050
# 	[1317] LOCATION    N070
# 	[1318] LOCATION    N140
# 	[1319] LOCATION    N600
# 	[1320] LOCATION    P020
# 	[1321] LOCATION    P230
# 	[1322] LOCATION    P260
# 	[1323] LOCATION    P280
# 	[1324] LOCATION    P380
# 	[1325] LOCATION    R150
# 	[1326] LOCATION    V208
# 	[1327] LOCATION    B010
# 	[1328] LOCATION    B190
# 	[1329] LOCATION    B030
# 	[1330] LOCATION    B150
# 	[1331] LOCATION    B160
# 	[1332] LOCATION    B170
# 	[1333] LOCATION    B270
# 	[1334] LOCATION    B290
# 	[1335] LOCATION    B330
# 	[1336] LOCATION    B350
# 	[1337] LOCATION    B370
# 	[1338] LOCATION    B420
# 	[1339] LOCATION    D070
# 	[1340] LOCATION    D090
# 	[1341] LOCATION    D100
# 	[1342] LOCATION    D120
# 	[1343] LOCATION    D180
# 	[1344] LOCATION    D241
# 	[1345] LOCATION    D260
# 	[1346] LOCATION    D310
# 	[1347] LOCATION    D350
# 	[1348] LOCATION    D390
# 	[1349] LOCATION    D420
# 	[1350] LOCATION    D430
# 	[1351] LOCATION    D440
# 	[1352] LOCATION    D470
# 	[1353] LOCATION    D480
# 	[1354] LOCATION    D500
# 	[1355] LOCATION    D600
# 	[1356] LOCATION    E070
# 	[1357] LOCATION    E130
# 	[1358] LOCATION    E140
# 	[1359] LOCATION    E250
# 	[1360] LOCATION    E300
# 	[1361] LOCATION    E30A
# 	[1362] LOCATION    E330
# 	[1363] LOCATION    E459
# 	[1364] LOCATION    E480
# 	[1365] LOCATION    E490
# 	[1366] LOCATION    E500
# 	[1367] LOCATION    H070
# 	[1368] LOCATION    H160
# 	[1369] LOCATION    H190
# 	[1370] LOCATION    H200
# 	[1371] LOCATION    H270
# 	[1372] LOCATION    H330
# 	[1373] LOCATION    H360
# 	[1374] LOCATION    H370
# 	[1375] LOCATION    H430
# 	[1376] LOCATION    H510
# 	[1377] LOCATION    N020
# 	[1378] LOCATION    N02P
# 	[1379] LOCATION    N030
# 	[1380] LOCATION    N03C
# 	[1381] LOCATION    N050
# 	[1382] LOCATION    N070
# 	[1383] LOCATION    N140
# 	[1384] LOCATION    N600
# 	[1385] LOCATION    P020
# 	[1386] LOCATION    P230
# 	[1387] LOCATION    P260
# 	[1388] LOCATION    P280
# 	[1389] LOCATION    R150
# 	[1390] LOCATION    B010
# 	[1391] LOCATION    B190
# 	[1392] LOCATION    B030
# 	[1393] LOCATION    B150
# 	[1394] LOCATION    B160
# 	[1395] LOCATION    B170
# 	[1396] LOCATION    B270
# 	[1397] LOCATION    B290
# 	[1398] LOCATION    B330
# 	[1399] LOCATION    B350
# 	[1400] LOCATION    B370
# 	[1401] LOCATION    B420
# 	[1402] LOCATION    D070
# 	[1403] LOCATION    D090
# 	[1404] LOCATION    D100
# 	[1405] LOCATION    D120
# 	[1406] LOCATION    D180
# 	[1407] LOCATION    D241
# 	[1408] LOCATION    D260
# 	[1409] LOCATION    D310
# 	[1410] LOCATION    D350
# 	[1411] LOCATION    D390
# 	[1412] LOCATION    D420
# 	[1413] LOCATION    D430
# 	[1414] LOCATION    D440
# 	[1415] LOCATION    D470
# 	[1416] LOCATION    D480
# 	[1417] LOCATION    D500
# 	[1418] LOCATION    D600
# 	[1419] LOCATION    E070
# 	[1420] LOCATION    E130
# 	[1421] LOCATION    E140
# 	[1422] LOCATION    E250
# 	[1423] LOCATION    E300
# 	[1424] LOCATION    E30A
# 	[1425] LOCATION    E330
# 	[1426] LOCATION    E459
# 	[1427] LOCATION    E480
# 	[1428] LOCATION    E490
# 	[1429] LOCATION    E500
# 	[1430] LOCATION    H070
# 	[1431] LOCATION    H160
# 	[1432] LOCATION    H190
# 	[1433] LOCATION    H200
# 	[1434] LOCATION    H270
# 	[1435] LOCATION    H330
# 	[1436] LOCATION    H360
# 	[1437] LOCATION    H370
# 	[1438] LOCATION    H430
# 	[1439] LOCATION    H510
# 	[1440] LOCATION    N020
# 	[1441] LOCATION    N02P
# 	[1442] LOCATION    N030
# 	[1443] LOCATION    N03C
# 	[1444] LOCATION    N050
# 	[1445] LOCATION    N070
# 	[1446] LOCATION    N140
# 	[1447] LOCATION    N600
# 	[1448] LOCATION    P020
# 	[1449] LOCATION    P230
# 	[1450] LOCATION    P280
# 	[1451] LOCATION    P380
# 	[1452] LOCATION    R150
# 	[1453] LOCATION    V208
# 	[1454] LOCATION    source-9
# 	[1455] LOCATION    P050
# 	[1456] LOCATION    P280
# 	[1457] LOCATION    R400
# 	[1458] LOCATION    U060
# 	[1459] LOCATION    U170
# 	[1460] LOCATION    B010
# 	[1461] LOCATION    B190
# 	[1462] LOCATION    B030
# 	[1463] LOCATION    B150
# 	[1464] LOCATION    B160
# 	[1465] LOCATION    B170
# 	[1466] LOCATION    B270
# 	[1467] LOCATION    B290
# 	[1468] LOCATION    B330
# 	[1469] LOCATION    B350
# 	[1470] LOCATION    B370
# 	[1471] LOCATION    B420
# 	[1472] LOCATION    D070
# 	[1473] LOCATION    D090
# 	[1474] LOCATION    D100
# 	[1475] LOCATION    D120
# 	[1476] LOCATION    D180
# 	[1477] LOCATION    D241
# 	[1478] LOCATION    D260
# 	[1479] LOCATION    D310
# 	[1480] LOCATION    D350
# 	[1481] LOCATION    D390
# 	[1482] LOCATION    D420
# 	[1483] LOCATION    D430
# 	[1484] LOCATION    D440
# 	[1485] LOCATION    D470
# 	[1486] LOCATION    D480
# 	[1487] LOCATION    D500
# 	[1488] LOCATION    D600
# 	[1489] LOCATION    E070
# 	[1490] LOCATION    E130
# 	[1491] LOCATION    E140
# 	[1492] LOCATION    E250
# 	[1493] LOCATION    E300
# 	[1494] LOCATION    E30A
# 	[1495] LOCATION    E330
# 	[1496] LOCATION    E459
# 	[1497] LOCATION    E480
# 	[1498] LOCATION    E490
# 	[1499] LOCATION    E500
# 	[1500] LOCATION    H070
# 	[1501] LOCATION    H160
# 	[1502] LOCATION    H190
# 	[1503] LOCATION    H200
# 	[1504] LOCATION    H270
# 	[1505] LOCATION    H330
# 	[1506] LOCATION    H360
# 	[1507] LOCATION    H370
# 	[1508] LOCATION    H430
# 	[1509] LOCATION    H510
# 	[1510] LOCATION    N020
# 	[1511] LOCATION    N02P
# 	[1512] LOCATION    N030
# 	[1513] LOCATION    N03C
# 	[1514] LOCATION    N050
# 	[1515] LOCATION    N070
# 	[1516] LOCATION    N140
# 	[1517] LOCATION    N600
# 	[1518] LOCATION    P280
# 	[1519] LOCATION    R150
# 	[1520] LOCATION    B010
# 	[1521] LOCATION    B190
# 	[1522] LOCATION    B030
# 	[1523] LOCATION    B150
# 	[1524] LOCATION    B160
# 	[1525] LOCATION    B170
# 	[1526] LOCATION    B270
# 	[1527] LOCATION    B290
# 	[1528] LOCATION    B330
# 	[1529] LOCATION    B350
# 	[1530] LOCATION    B370
# 	[1531] LOCATION    B420
# 	[1532] LOCATION    D070
# 	[1533] LOCATION    D090
# 	[1534] LOCATION    D100
# 	[1535] LOCATION    D120
# 	[1536] LOCATION    D180
# 	[1537] LOCATION    D241
# 	[1538] LOCATION    D260
# 	[1539] LOCATION    D310
# 	[1540] LOCATION    D350
# 	[1541] LOCATION    D390
# 	[1542] LOCATION    D420
# 	[1543] LOCATION    D430
# 	[1544] LOCATION    D440
# 	[1545] LOCATION    D470
# 	[1546] LOCATION    D480
# 	[1547] LOCATION    D500
# 	[1548] LOCATION    D600
# 	[1549] LOCATION    E070
# 	[1550] LOCATION    E130
# 	[1551] LOCATION    E140
# 	[1552] LOCATION    E250
# 	[1553] LOCATION    E300
# 	[1554] LOCATION    E30A
# 	[1555] LOCATION    E330
# 	[1556] LOCATION    E459
# 	[1557] LOCATION    E480
# 	[1558] LOCATION    E490
# 	[1559] LOCATION    E500
# 	[1560] LOCATION    H070
# 	[1561] LOCATION    H160
# 	[1562] LOCATION    H190
# 	[1563] LOCATION    H200
# 	[1564] LOCATION    H270
# 	[1565] LOCATION    H330
# 	[1566] LOCATION    H360
# 	[1567] LOCATION    H370
# 	[1568] LOCATION    H430
# 	[1569] LOCATION    H510
# 	[1570] LOCATION    N020
# 	[1571] LOCATION    N02P
# 	[1572] LOCATION    N030
# 	[1573] LOCATION    N03C
# 	[1574] LOCATION    N050
# 	[1575] LOCATION    N070
# 	[1576] LOCATION    N140
# 	[1577] LOCATION    N600
# 	[1578] LOCATION    P280
# 	[1579] LOCATION    R150
# 	[1580] LOCATION    V208
# 	[1581] LOCATION    source-12
# 	[1582] LOCATION    P050
# 	[1583] LOCATION    P120
# 	[1584] LOCATION    P210
# 	[1585] LOCATION    P340
# 	[1586] LOCATION    P370
# 	[1587] LOCATION    R070
# 	[1588] LOCATION    R080
# 	[1589] LOCATION    R095
# 	[1590] LOCATION    R400
# 	[1591] LOCATION    R440
# 	[1592] LOCATION    R460
# 	[1593] LOCATION    U060
# 	[1594] LOCATION    U170
# 	[1595] LOCATION    source-13
# 	[1596] LOCATION    source-15
# 	[1597] LOCATION    R080
# 	[1598] LOCATION    R180
# 	[1599] LOCATION    R400
# 	[1600] LOCATION    R440
# 	[1601] LOCATION    R460
# 	[1602] LOCATION    U060
# 	[1603] LOCATION    U170
# 	[1604] LOCATION    source-14
# 	[1605] LOCATION    R050
# 	[1606] LOCATION    R070
# 	[1607] LOCATION    R095
# 	[1608] LOCATION    R100
# 	[1609] LOCATION    R120
# 	[1610] LOCATION    R400
# 	[1611] LOCATION    U060
# 	[1612] LOCATION    U170
# 	[1613] LOCATION    P160
# 	[1614] LOCATION    P310
# 	[1615] LOCATION    P420
# 	[1616] LOCATION    R070
# 	[1617] LOCATION    R095
# 	[1618] LOCATION    R160
# 	[1619] LOCATION    R350
# 	[1620] LOCATION    R400
# 	[1621] LOCATION    R460
# 	[1622] LOCATION    U060
# 	[1623] LOCATION    U170
# 	[1624] LOCATION    source-16
# 	[1625] LOCATION    P050
# 	[1626] LOCATION    R050
# 	[1627] LOCATION    R100
# 	[1628] LOCATION    R120
# 	[1629] LOCATION    R180
# 	[1630] LOCATION    R200
# 	[1631] LOCATION    R400
# 	[1632] LOCATION    U060
# 	[1633] LOCATION    U170
# 	[1634] LOCATION    source-17
# 	[1635] LOCATION    P050
# 	[1636] LOCATION    R050
# 	[1637] LOCATION    R100
# 	[1638] LOCATION    R160
# 	[1639] LOCATION    R180
# 	[1640] LOCATION    R200
# 	[1641] LOCATION    R350
# 	[1642] LOCATION    R400
# 	[1643] LOCATION    U060
# 	[1644] LOCATION    U170
# 	[1645] LOCATION    source-18
# 	[1646] LOCATION    K310
# 	[1647] LOCATION    M610
# 	[1648] LOCATION    source-19
# 	[1649] LOCATION    K310
# 	[1650] LOCATION    K600
# 	[1651] LOCATION    L010
# 	[1652] LOCATION    L030
# 	[1653] LOCATION    L040
# 	[1654] LOCATION    L080
# 	[1655] LOCATION    L110
# 	[1656] LOCATION    L240
# 	[1657] LOCATION    L24A
# 	[1658] LOCATION    L310
# 	[1659] LOCATION    L390
# 	[1660] LOCATION    L400
# 	[1661] LOCATION    M030
# 	[1662] LOCATION    M040
# 	[1663] LOCATION    M180
# 	[1664] LOCATION    M512
# 	[1665] LOCATION    M530
# 	[1666] LOCATION    V27E
# 	[1667] LOCATION    V27F
# 	[1668] LOCATION    V27U
# 	[1669] LOCATION    V351
# 	[1670] LOCATION    X080
# 	[1671] LOCATION    X150
# 	[1672] LOCATION    X171
# 	[1673] LOCATION    X190
# 	[1674] LOCATION    X191
# 	[1675] LOCATION    X260
# 	[1676] LOCATION    X320
# 	[1677] LOCATION    X350
# 	[1678] LOCATION    X355
# 	[1679] LOCATION    X490
# 	[1680] LOCATION    source-20
# 	[1681] LOCATION    source-21
# 	[1682] LOCATION    source-22
# 	[1683] LOCATION    source-24
# 	[1684] LOCATION    source-25
# 	[1685] LOCATION    K310
# 	[1686] LOCATION    L010
# 	[1687] LOCATION    L030
# 	[1688] LOCATION    L040
# 	[1689] LOCATION    L080
# 	[1690] LOCATION    L100
# 	[1691] LOCATION    L110
# 	[1692] LOCATION    L240
# 	[1693] LOCATION    L24A
# 	[1694] LOCATION    L310
# 	[1695] LOCATION    L390
# 	[1696] LOCATION    L400
# 	[1697] LOCATION    M030
# 	[1698] LOCATION    M040
# 	[1699] LOCATION    M180
# 	[1700] LOCATION    M512
# 	[1701] LOCATION    M530
# 	[1702] LOCATION    V27E
# 	[1703] LOCATION    V27F
# 	[1704] LOCATION    V27U
# 	[1705] LOCATION    V351
# 	[1706] LOCATION    X080
# 	[1707] LOCATION    X150
# 	[1708] LOCATION    X171
# 	[1709] LOCATION    X190
# 	[1710] LOCATION    X191
# 	[1711] LOCATION    X320
# 	[1712] LOCATION    X350
# 	[1713] LOCATION    X355
# 	[1714] LOCATION    X490
# 	[1715] LOCATION    K310
# 	[1716] LOCATION    L010
# 	[1717] LOCATION    L030
# 	[1718] LOCATION    L040
# 	[1719] LOCATION    L080
# 	[1720] LOCATION    L100
# 	[1721] LOCATION    L110
# 	[1722] LOCATION    L240
# 	[1723] LOCATION    L24A
# 	[1724] LOCATION    L310
# 	[1725] LOCATION    L390
# 	[1726] LOCATION    L400
# 	[1727] LOCATION    M030
# 	[1728] LOCATION    M040
# 	[1729] LOCATION    M180
# 	[1730] LOCATION    M450
# 	[1731] LOCATION    M512
# 	[1732] LOCATION    M530
# 	[1733] LOCATION    V27E
# 	[1734] LOCATION    V27F
# 	[1735] LOCATION    V27U
# 	[1736] LOCATION    V351
# 	[1737] LOCATION    X080
# 	[1738] LOCATION    X150
# 	[1739] LOCATION    X171
# 	[1740] LOCATION    X190
# 	[1741] LOCATION    X191
# 	[1742] LOCATION    X260
# 	[1743] LOCATION    X320
# 	[1744] LOCATION    X350
# 	[1745] LOCATION    X355
# 	[1746] LOCATION    X490
# 	[1747] LOCATION    K310
# 	[1748] LOCATION    K666
# 	[1749] LOCATION    L010
# 	[1750] LOCATION    L030
# 	[1751] LOCATION    L040
# 	[1752] LOCATION    L080
# 	[1753] LOCATION    L100
# 	[1754] LOCATION    L110
# 	[1755] LOCATION    L240
# 	[1756] LOCATION    L24A
# 	[1757] LOCATION    L310
# 	[1758] LOCATION    L390
# 	[1759] LOCATION    L400
# 	[1760] LOCATION    M030
# 	[1761] LOCATION    M040
# 	[1762] LOCATION    M080
# 	[1763] LOCATION    M180
# 	[1764] LOCATION    M400
# 	[1765] LOCATION    M450
# 	[1766] LOCATION    M512
# 	[1767] LOCATION    M530
# 	[1768] LOCATION    M620
# 	[1769] LOCATION    Q160
# 	[1770] LOCATION    V27E
# 	[1771] LOCATION    V27F
# 	[1772] LOCATION    V27U
# 	[1773] LOCATION    V351
# 	[1774] LOCATION    X080
# 	[1775] LOCATION    X150
# 	[1776] LOCATION    X171
# 	[1777] LOCATION    X190
# 	[1778] LOCATION    X191
# 	[1779] LOCATION    X320
# 	[1780] LOCATION    X350
# 	[1781] LOCATION    X355
# 	[1782] LOCATION    X490
# 	[1783] LOCATION    X540
# 	[1784] LOCATION    source-26
# 	[1785] LOCATION    source-23
# 	[1786] LOCATION    K310
# 	[1787] LOCATION    K610
# 	[1788] LOCATION    K620
# 	[1789] LOCATION    K630
# 	[1790] LOCATION    K645
# 	[1791] LOCATION    X490
# 	[1792] LOCATION    J122
# 	[1793] LOCATION    L010
# 	[1794] LOCATION    L030
# 	[1795] LOCATION    L040
# 	[1796] LOCATION    L080
# 	[1797] LOCATION    L100
# 	[1798] LOCATION    L110
# 	[1799] LOCATION    L240
# 	[1800] LOCATION    L24A
# 	[1801] LOCATION    L310
# 	[1802] LOCATION    L390
# 	[1803] LOCATION    L400
# 	[1804] LOCATION    M030
# 	[1805] LOCATION    M040
# 	[1806] LOCATION    M180
# 	[1807] LOCATION    M450
# 	[1808] LOCATION    M512
# 	[1809] LOCATION    M530
# 	[1810] LOCATION    V27E
# 	[1811] LOCATION    V27F
# 	[1812] LOCATION    V27U
# 	[1813] LOCATION    V351
# 	[1814] LOCATION    X080
# 	[1815] LOCATION    X150
# 	[1816] LOCATION    X171
# 	[1817] LOCATION    X190
# 	[1818] LOCATION    X191
# 	[1819] LOCATION    X320
# 	[1820] LOCATION    X350
# 	[1821] LOCATION    X355
# 	[1822] LOCATION    X490
# 	[1823] LOCATION    L010
# 	[1824] LOCATION    L030
# 	[1825] LOCATION    L040
# 	[1826] LOCATION    L080
# 	[1827] LOCATION    L100
# 	[1828] LOCATION    L110
# 	[1829] LOCATION    L240
# 	[1830] LOCATION    L24A
# 	[1831] LOCATION    L310
# 	[1832] LOCATION    L390
# 	[1833] LOCATION    L400
# 	[1834] LOCATION    M030
# 	[1835] LOCATION    M040
# 	[1836] LOCATION    M080
# 	[1837] LOCATION    M180
# 	[1838] LOCATION    M450
# 	[1839] LOCATION    M512
# 	[1840] LOCATION    M530
# 	[1841] LOCATION    Q160
# 	[1842] LOCATION    V255
# 	[1843] LOCATION    V27E
# 	[1844] LOCATION    V27F
# 	[1845] LOCATION    V27U
# 	[1846] LOCATION    V351
# 	[1847] LOCATION    V362
# 	[1848] LOCATION    V363
# 	[1849] LOCATION    X080
# 	[1850] LOCATION    X150
# 	[1851] LOCATION    X171
# 	[1852] LOCATION    X190
# 	[1853] LOCATION    X191
# 	[1854] LOCATION    X320
# 	[1855] LOCATION    X350
# 	[1856] LOCATION    X355
# 	[1857] LOCATION    K491
# 	[1858] LOCATION    K625
# 	[1859] LOCATION    K666
# 	[1860] LOCATION    M080
# 	[1861] LOCATION    M400
# 	[1862] LOCATION    M450
# 	[1863] LOCATION    M620
# 	[1864] LOCATION    Q160
# 	[1865] LOCATION    source-27
# 	[1866] LOCATION    K02A
# 	[1867] LOCATION    K030
# 	[1868] LOCATION    source-28
# 	[1869] LOCATION    J090
# 	[1870] LOCATION    J093
# 	[1871] LOCATION    J09R
# 	[1872] LOCATION    J09T
# 	[1873] LOCATION    J250
# 	[1874] LOCATION    J251
# 	[1875] LOCATION    J25C
# 	[1876] LOCATION    J25D
# 	[1877] LOCATION    source-29
# 	[1878] LOCATION    J090
# 	[1879] LOCATION    J093
# 	[1880] LOCATION    J09R
# 	[1881] LOCATION    J09T
# 	[1882] LOCATION    J250
# 	[1883] LOCATION    J251
# 	[1884] LOCATION    J25C
# 	[1885] LOCATION    J25D
# 	[1886] LOCATION    J300
# 	[1887] LOCATION    source-30
# 	[1888] LOCATION    J010
# 	[1889] LOCATION    J016
# 	[1890] LOCATION    J018
# 	[1891] LOCATION    J021
# 	[1892] LOCATION    J022
# 	[1893] LOCATION    J050
# 	[1894] LOCATION    J0AA
# 	[1895] LOCATION    J121
# 	[1896] LOCATION    J440
# 	[1897] LOCATION    J490
# 	[1898] LOCATION    J520
# 	[1899] LOCATION    V234
# 	[1900] LOCATION    V237
# 	[1901] LOCATION    V262
# 	[1902] LOCATION    V266
# 	[1903] LOCATION    E11
# 	[1904] LOCATION    source-32
# 	[1905] LOCATION    source-31
# 	[1906] LOCATION    J210
# 	[1907] LOCATION    J010
# 	[1908] LOCATION    J016
# 	[1909] LOCATION    J018
# 	[1910] LOCATION    J021
# 	[1911] LOCATION    J022
# 	[1912] LOCATION    J050
# 	[1913] LOCATION    J080
# 	[1914] LOCATION    J0AA
# 	[1915] LOCATION    J121
# 	[1916] LOCATION    J440
# 	[1917] LOCATION    J490
# 	[1918] LOCATION    J540
# 	[1919] LOCATION    J560
# 	[1920] LOCATION    V234
# 	[1921] LOCATION    V237
# 	[1922] LOCATION    source-33
# 	[1923] LOCATION    T010
# 	[1924] LOCATION    T070
# 	[1925] LOCATION    T080
# 	[1926] LOCATION    source-34
# 	[1927] LOCATION    W220
# 	[1928] LOCATION    W230
# 	[1929] LOCATION    W310
# 	[1930] LOCATION    W611
# 	[1931] LOCATION    W670
# 	[1932] LOCATION    W720
# 	[1933] LOCATION    V234
# 	[1934] LOCATION    V237
# 	[1935] LOCATION    source-35
# 	[1936] LOCATION    W220
# 	[1937] LOCATION    W230
# 	[1938] LOCATION    W310
# 	[1939] LOCATION    W611
# 	[1940] LOCATION    W670
# 	[1941] LOCATION    W720
# 	[1942] LOCATION    source-36
# 	[1943] LOCATION    T010
# 	[1944] LOCATION    T070
# 	[1945] LOCATION    T080
# 	[1946] LOCATION    T120
# 	[1947] LOCATION    source-37
# 	[1948] LOCATION    source-38
# 	[1949] LOCATION    T030
# 	[1950] LOCATION    T040
# 	[1951] LOCATION    T080
# 	[1952] LOCATION    T120
# 	[1953] LOCATION    T010
# 	[1954] LOCATION    T030
# 	[1955] LOCATION    T080
# 	[1956] LOCATION    T120
# ...
# 	[17574] TRANSPORTER  Z7==>E8 (40ft) | Z7 ==> E8 | 88.2420943/per unit | 106.2887866 hrs |
# 	[17575] TRANSPORTER  Z7==>E8 (roro) | Z7 ==> E8 | 277.48/per unit | 157.6 hrs |
# 	[17576] TRANSPORTER  Z7==>E9 (20ft) | Z7 ==> E9 | 180.788681/per unit | 106.2887866 hrs |
# 	[17577] TRANSPORTER  Z7==>E9 (40ft) | Z7 ==> E9 | 88.2420943/per unit | 106.2887866 hrs |
# 	[17578] TRANSPORTER  Z7==>E9 (roro) | Z7 ==> E9 | 277.48/per unit | 157.6 hrs |
# 	[17579] TRANSPORTER  Z7==>E10 (20ft) | Z7 ==> E10 | 112.9929257/per unit | 66.43049162 hrs |
# 	[17580] TRANSPORTER  Z7==>E10 (40ft) | Z7 ==> E10 | 55.15130894/per unit | 66.43049162 hrs |
# 	[17581] TRANSPORTER  Z7==>E10 (roro) | Z7 ==> E10 | 173.425/per unit | 98.5 hrs |
# 	[17582] TRANSPORTER  Z7==>E11 (20ft) | Z7 ==> E11 | 79.09504795/per unit | 46.50134413 hrs |
# 	[17583] TRANSPORTER  Z7==>E11 (40ft) | Z7 ==> E11 | 38.60591626/per unit | 46.50134413 hrs |
# 	[17584] TRANSPORTER  Z7==>E11 (roro) | Z7 ==> E11 | 121.4/per unit | 68.9 hrs |
# 	[17585] TRANSPORTER  Z7==>M1 (20ft) | Z7 ==> M1 | 120.1393707/per unit | 86.07046446 hrs |
# 	[17586] TRANSPORTER  Z7==>M1 (40ft) | Z7 ==> M1 | 58.63945471/per unit | 86.07046446 hrs |
# 	[17587] TRANSPORTER  Z7==>M1 (roro) | Z7 ==> M1 | 160.105/per unit | 77.8 hrs |
# 	[17588] TRANSPORTER  Z7==>M2 (20ft) | Z7 ==> M2 | 108.1254336/per unit | 77.46341801 hrs |
# 	[17589] TRANSPORTER  Z7==>M2 (40ft) | Z7 ==> M2 | 52.77550924/per unit | 77.46341801 hrs |
# 	[17590] TRANSPORTER  Z7==>M2 (roro) | Z7 ==> M2 | 144.09/per unit | 70.0 hrs |
# 	[17591] TRANSPORTER  Z7==>M3 (20ft) | Z7 ==> M3 | 96.1114965/per unit | 68.85637157 hrs |
# 	[17592] TRANSPORTER  Z7==>M3 (40ft) | Z7 ==> M3 | 46.91156377/per unit | 68.85637157 hrs |
# 	[17593] TRANSPORTER  Z7==>M3 (roro) | Z7 ==> M3 | 128.08/per unit | 62.2 hrs |
# 	[17594] TRANSPORTER  Z7==>M4 (20ft) | Z7 ==> M4 | 108.1254336/per unit | 77.46341801 hrs |
# 	[17595] TRANSPORTER  Z7==>M4 (40ft) | Z7 ==> M4 | 52.77550924/per unit | 77.46341801 hrs |
# 	[17596] TRANSPORTER  Z7==>M4 (roro) | Z7 ==> M4 | 144.09/per unit | 70.0 hrs |
# 	[17597] TRANSPORTER  Z7==>M5 (20ft) | Z7 ==> M5 | 115.5407678/per unit | 57.98338344 hrs |
# 	[17598] TRANSPORTER  Z7==>M5 (40ft) | Z7 ==> M5 | 56.39489853/per unit | 57.98338344 hrs |
# 	[17599] TRANSPORTER  Z7==>M5 (roro) | Z7 ==> M5 | 126.5/per unit | 75.9 hrs |
# 	[17600] TRANSPORTER  Z7==>M6 (20ft) | Z7 ==> M6 | 128.3786308/per unit | 64.4259816 hrs |
# 	[17601] TRANSPORTER  Z7==>M6 (40ft) | Z7 ==> M6 | 62.66099837/per unit | 64.4259816 hrs |
# 	[17602] TRANSPORTER  Z7==>M6 (roro) | Z7 ==> M6 | 140.555/per unit | 84.3 hrs |
# 	[17603] TRANSPORTER  Z7==>M7 (20ft) | Z7 ==> M7 | 156.1811818/per unit | 111.8916038 hrs |
# 	[17604] TRANSPORTER  Z7==>M7 (40ft) | Z7 ==> M7 | 76.23129113/per unit | 111.8916038 hrs |
# 	[17605] TRANSPORTER  Z7==>M7 (roro) | Z7 ==> M7 | 208.135/per unit | 101.1 hrs |
# 	[17606] TRANSPORTER  Z7==>M8 (20ft) | Z7 ==> M8 | 180.209056/per unit | 129.1056967 hrs |
# 	[17607] TRANSPORTER  Z7==>M8 (40ft) | Z7 ==> M8 | 87.95918207/per unit | 129.1056967 hrs |
# 	[17608] TRANSPORTER  Z7==>M8 (roro) | Z7 ==> M8 | 240.155/per unit | 116.7 hrs |
# 	[17609] TRANSPORTER  Z7==>M9 (20ft) | Z7 ==> M9 | 156.1811818/per unit | 111.8916038 hrs |
# 	[17610] TRANSPORTER  Z7==>M9 (40ft) | Z7 ==> M9 | 76.23129113/per unit | 111.8916038 hrs |
# 	[17611] TRANSPORTER  Z7==>M9 (roro) | Z7 ==> M9 | 208.135/per unit | 101.1 hrs |
# 	[17612] TRANSPORTER  Z7==>M10 (20ft) | Z7 ==> M10 | 144.1672448/per unit | 103.2845573 hrs |
# 	[17613] TRANSPORTER  Z7==>M10 (40ft) | Z7 ==> M10 | 70.36734566/per unit | 103.2845573 hrs |
# 	[17614] TRANSPORTER  Z7==>M10 (roro) | Z7 ==> M10 | 192.125/per unit | 93.3 hrs |
# 	[17615] TRANSPORTER  Z7==>M11 (20ft) | Z7 ==> M11 | 97.66273245/per unit | 63.61433355 hrs |
# 	[17616] TRANSPORTER  Z7==>M11 (40ft) | Z7 ==> M11 | 47.66871465/per unit | 63.61433355 hrs |
# 	[17617] TRANSPORTER  Z7==>M11 (roro) | Z7 ==> M11 | 141.27/per unit | 71.9 hrs |
# 	[17618] TRANSPORTER  Z7==>M12 (20ft) | Z7 ==> M12 | 168.1951189/per unit | 120.4986502 hrs |
# 	[17619] TRANSPORTER  Z7==>M12 (40ft) | Z7 ==> M12 | 82.0952366/per unit | 120.4986502 hrs |
# 	[17620] TRANSPORTER  Z7==>M12 (roro) | Z7 ==> M12 | 224.145/per unit | 108.9 hrs |
# 	[17621] TRANSPORTER  Z7==>M13 (20ft) | Z7 ==> M13 | 89.5241714/per unit | 58.31313909 hrs |
# 	[17622] TRANSPORTER  Z7==>M13 (40ft) | Z7 ==> M13 | 43.69632176/per unit | 58.31313909 hrs |
# 	[17623] TRANSPORTER  Z7==>M13 (roro) | Z7 ==> M13 | 129.495/per unit | 65.9 hrs |
# 	[17624] TRANSPORTER  Z7==>K1 (20ft) | Z7 ==> K1 | 96.1114965/per unit | 68.85637157 hrs |
# 	[17625] TRANSPORTER  Z7==>K1 (40ft) | Z7 ==> K1 | 46.91156377/per unit | 68.85637157 hrs |
# 	[17626] TRANSPORTER  Z7==>K1 (roro) | Z7 ==> K1 | 128.08/per unit | 62.2 hrs |
# 	[17627] TRANSPORTER  Z7==>K2 (20ft) | Z7 ==> K2 | 65.1084883/per unit | 42.4095557 hrs |
# 	[17628] TRANSPORTER  Z7==>K2 (40ft) | Z7 ==> K2 | 31.7791431/per unit | 42.4095557 hrs |
# 	[17629] TRANSPORTER  Z7==>K2 (roro) | Z7 ==> K2 | 94.18/per unit | 47.9 hrs |
# 	[17630] TRANSPORTER  Z7==>K3 (20ft) | Z7 ==> K3 | 108.1254336/per unit | 77.46341801 hrs |
# 	[17631] TRANSPORTER  Z7==>K3 (40ft) | Z7 ==> K3 | 52.77550924/per unit | 77.46341801 hrs |
# 	[17632] TRANSPORTER  Z7==>K3 (roro) | Z7 ==> K3 | 144.09/per unit | 70.0 hrs |
# 	[17633] TRANSPORTER  Z7==>K4 (20ft) | Z7 ==> K4 | 89.86504155/per unit | 45.09818712 hrs |
# 	[17634] TRANSPORTER  Z7==>K4 (40ft) | Z7 ==> K4 | 43.86269886/per unit | 45.09818712 hrs |
# 	[17635] TRANSPORTER  Z7==>K4 (roro) | Z7 ==> K4 | 98.39/per unit | 59.0 hrs |
# 	[17636] TRANSPORTER  Z7==>K5 (20ft) | Z7 ==> K5 | 96.1114965/per unit | 68.85637157 hrs |
# 	[17637] TRANSPORTER  Z7==>K5 (40ft) | Z7 ==> K5 | 46.91156377/per unit | 68.85637157 hrs |
# 	[17638] TRANSPORTER  Z7==>K5 (roro) | Z7 ==> K5 | 128.08/per unit | 62.2 hrs |
# 	[17639] TRANSPORTER  Z7==>A1 (20ft) | Z7 ==> A1 | 67.7957554/per unit | 39.85829497 hrs |
# 	[17640] TRANSPORTER  Z7==>A1 (40ft) | Z7 ==> A1 | 33.09078536/per unit | 39.85829497 hrs |
# 	[17641] TRANSPORTER  Z7==>A1 (roro) | Z7 ==> A1 | 104.055/per unit | 59.1 hrs |
# 	[17642] TRANSPORTER  Z7==>A2 (20ft) | Z7 ==> A2 | 123.2410358/per unit | 45.51757926 hrs |
# 	[17643] TRANSPORTER  Z7==>A2 (40ft) | Z7 ==> A2 | 60.15336269/per unit | 45.51757926 hrs |
# 	[17644] TRANSPORTER  Z7==>A2 (roro) | Z7 ==> A2 | 65.12/per unit | 56.4 hrs |
# 	[17645] TRANSPORTER  Z7==>A3 (20ft) | Z7 ==> A3 | 123.2410358/per unit | 45.51757926 hrs |
# 	[17646] TRANSPORTER  Z7==>A3 (40ft) | Z7 ==> A3 | 60.15336269/per unit | 45.51757926 hrs |
# 	[17647] TRANSPORTER  Z7==>A3 (roro) | Z7 ==> A3 | 65.12/per unit | 56.4 hrs |
# 	[17648] TRANSPORTER  Z7==>A4 (20ft) | Z7 ==> A4 | 123.2410358/per unit | 45.51757926 hrs |
# 	[17649] TRANSPORTER  Z7==>A4 (40ft) | Z7 ==> A4 | 60.15336269/per unit | 45.51757926 hrs |
# 	[17650] TRANSPORTER  Z7==>A4 (roro) | Z7 ==> A4 | 65.12/per unit | 56.4 hrs |
# 	[17651] TRANSPORTER  Z7==>A5 (20ft) | Z7 ==> A5 | 36.04181119/per unit | 25.82113934 hrs |
# 	[17652] TRANSPORTER  Z7==>A5 (40ft) | Z7 ==> A5 | 17.59183641/per unit | 25.82113934 hrs |
# 	[17653] TRANSPORTER  Z7==>A5 (roro) | Z7 ==> A5 | 48.03/per unit | 23.3 hrs |
# 	[17654] TRANSPORTER  Z7==>A6 (20ft) | Z7 ==> A6 | 60.0696853/per unit | 43.03523223 hrs |
# 	[17655] TRANSPORTER  Z7==>A6 (40ft) | Z7 ==> A6 | 29.31972736/per unit | 43.03523223 hrs |
# 	[17656] TRANSPORTER  Z7==>A6 (roro) | Z7 ==> A6 | 80.05/per unit | 38.9 hrs |
# 	[17657] TRANSPORTER  Z7==>A7 (20ft) | Z7 ==> A7 | 84.09755945/per unit | 60.24932512 hrs |
# 	[17658] TRANSPORTER  Z7==>A7 (40ft) | Z7 ==> A7 | 41.0476183/per unit | 60.24932512 hrs |
# 	[17659] TRANSPORTER  Z7==>A7 (roro) | Z7 ==> A7 | 112.07/per unit | 54.5 hrs |
# 	[17660] TRANSPORTER  Z7==>A8 (20ft) | Z7 ==> A8 | 48.05574826/per unit | 34.42818578 hrs |
# 	[17661] TRANSPORTER  Z7==>A8 (40ft) | Z7 ==> A8 | 23.45578189/per unit | 34.42818578 hrs |
# 	[17662] TRANSPORTER  Z7==>A8 (roro) | Z7 ==> A8 | 64.04/per unit | 31.1 hrs |
# 	[17663] TRANSPORTER  Z7==>A9 (20ft) | Z7 ==> A9 | 60.0696853/per unit | 43.03523223 hrs |
# 	[17664] TRANSPORTER  Z7==>A9 (40ft) | Z7 ==> A9 | 29.31972736/per unit | 43.03523223 hrs |
# 	[17665] TRANSPORTER  Z7==>A9 (roro) | Z7 ==> A9 | 80.05/per unit | 38.9 hrs |
# 	[17666] TRANSPORTER  Z7==>A10 (20ft) | Z7 ==> A10 | 22.59858513/per unit | 13.28609832 hrs |
# 	[17667] TRANSPORTER  Z7==>A10 (40ft) | Z7 ==> A10 | 11.03026179/per unit | 13.28609832 hrs |
# 	[17668] TRANSPORTER  Z7==>A10 (roro) | Z7 ==> A10 | 34.685/per unit | 19.7 hrs |
# 	[17669] TRANSPORTER  Z7==>A11 (20ft) | Z7 ==> A11 | 27.54148041/per unit | 14.89422554 hrs |
# 	[17670] TRANSPORTER  Z7==>A11 (40ft) | Z7 ==> A11 | 13.44286544/per unit | 14.89422554 hrs |
# 	[17671] TRANSPORTER  Z7==>A11 (roro) | Z7 ==> A11 | 40.17/per unit | 20.2 hrs |
# 	[17672] TRANSPORTER  Z7==>A12 (20ft) | Z7 ==> A12 | 79.09504795/per unit | 46.50134413 hrs |
# 	[17673] TRANSPORTER  Z7==>A12 (40ft) | Z7 ==> A12 | 38.60591626/per unit | 46.50134413 hrs |
# 	[17674] TRANSPORTER  Z7==>A12 (roro) | Z7 ==> A12 | 121.4/per unit | 68.9 hrs |
# 	[17675] TRANSPORTER  Z7==>A13 (20ft) | Z7 ==> A13 | 36.72197388/per unit | 19.85896738 hrs |
# 	[17676] TRANSPORTER  Z7==>A13 (40ft) | Z7 ==> A13 | 17.92382058/per unit | 19.85896738 hrs |
# 	[17677] TRANSPORTER  Z7==>A13 (roro) | Z7 ==> A13 | 53.56/per unit | 27.0 hrs |
# 	[17678] TRANSPORTER  Z7==>A14 (20ft) | Z7 ==> A14 | 102.7008632/per unit | 37.93131605 hrs |
# 	[17679] TRANSPORTER  Z7==>A14 (40ft) | Z7 ==> A14 | 50.12780224/per unit | 37.93131605 hrs |
# 	[17680] TRANSPORTER  Z7==>A14 (roro) | Z7 ==> A14 | 54.265/per unit | 47.0 hrs |
# 	[17681] TRANSPORTER  Z7==>Z1 (20ft) | Z7 ==> Z1 | 51.3514523/per unit | 25.77039264 hrs |
# 	[17682] TRANSPORTER  Z7==>Z1 (40ft) | Z7 ==> Z1 | 25.06439935/per unit | 25.77039264 hrs |
# 	[17683] TRANSPORTER  Z7==>Z1 (roro) | Z7 ==> Z1 | 56.225/per unit | 33.7 hrs |
# 	[17684] TRANSPORTER  Z7==>Z2 (20ft) | Z7 ==> Z2 | 64.1893154/per unit | 32.2129908 hrs |
# 	[17685] TRANSPORTER  Z7==>Z2 (40ft) | Z7 ==> Z2 | 31.33049918/per unit | 32.2129908 hrs |
# 	[17686] TRANSPORTER  Z7==>Z2 (roro) | Z7 ==> Z2 | 70.28/per unit | 42.2 hrs |
# 	[17687] TRANSPORTER  Z7==>Z3 (20ft) | Z7 ==> Z3 | 77.0271785/per unit | 38.65558896 hrs |
# 	[17688] TRANSPORTER  Z7==>Z3 (40ft) | Z7 ==> Z3 | 37.59659902/per unit | 38.65558896 hrs |
# 	[17689] TRANSPORTER  Z7==>Z3 (roro) | Z7 ==> Z3 | 84.335/per unit | 50.6 hrs |
# 	[17690] TRANSPORTER  Z7==>Z4 (20ft) | Z7 ==> Z4 | 77.0271785/per unit | 38.65558896 hrs |
# 	[17691] TRANSPORTER  Z7==>Z4 (40ft) | Z7 ==> Z4 | 37.59659902/per unit | 38.65558896 hrs |
# 	[17692] TRANSPORTER  Z7==>Z4 (roro) | Z7 ==> Z4 | 84.335/per unit | 50.6 hrs |
# 	[17693] TRANSPORTER  Z7==>Z5 (20ft) | Z7 ==> Z5 | 71.4383384/per unit | 37.96077959 hrs |
# 	[17694] TRANSPORTER  Z7==>Z5 (40ft) | Z7 ==> Z5 | 34.8687128/per unit | 37.96077959 hrs |
# 	[17695] TRANSPORTER  Z7==>Z5 (roro) | Z7 ==> Z5 | 69.105/per unit | 36.7 hrs |
# 	[17696] TRANSPORTER  Z7==>Z6 (20ft) | Z7 ==> Z6 | 82.6244412/per unit | 44.68267661 hrs |
# 	[17697] TRANSPORTER  Z7==>Z6 (40ft) | Z7 ==> Z6 | 40.32859631/per unit | 44.68267661 hrs |
# 	[17698] TRANSPORTER  Z7==>Z6 (roro) | Z7 ==> Z6 | 120.515/per unit | 60.7 hrs |
# 	[17699] MATERIAL    CA | quantity: 1 | length: 2.193445122 | width: 0.652439024 | height: 1.025 | cube: 1.466866425 | cube_per_container: 1618 | weight: 11368.20167 | weight_per_container: 2 | water_transport: 40ft | land_transport: Van | Produced by: source-6, source-21, source-17 |
# 	[17700] MATERIAL    Linkage | quantity: 1 | length: 0.0 | width: 0.0 | height: 0.72652439 | cube: 0.0 | cube_per_container: 0 | weight: 1937.142 | weight_per_container: 13 | water_transport: 40ft | land_transport: Van | Produced by: source-6, source-21 |
# 	[17701] MATERIAL    Axles | quantity: 2 | length: 0.857926829 | width: 0.0 | height: 0.0 | cube: 0.0 | cube_per_container: 0 | weight: 1359.391667 | weight_per_container: 18 | water_transport: 40ft | land_transport: Van | Produced by: source-6, source-21, source-17 |
# 	[17702] MATERIAL    Lights | quantity: 1 | length: 0.0 | width: 0.0 | height: 0.0 | cube: 0.0 | cube_per_container: 0 | weight: 20.97633333 | weight_per_container: 1229 | water_transport: 40ft | land_transport: Van | Produced by: source-6, source-21, source-17 |
# 	[17703] MATERIAL    Seat | quantity: 1 | length: 0.457317073 | width: 0.198170732 | height: 0.182926829 | cube: 0.585 | cube_per_container: 4058 | weight: 188.621 | weight_per_container: 136 | water_transport: 40ft | land_transport: Van | Produced by: source-6, source-21, source-17 |
# 	[17704] MATERIAL    Radio | quantity: 1 | length: 0.0 | width: 0.0 | height: 0.0 | cube: 0.0 | cube_per_container: 0 | weight: 10.675 | weight_per_container: 2414 | water_transport: 40ft | land_transport: Van | Produced by: source-6, source-21, source-17 |
# 	[17705] MATERIAL    Guard | quantity: 1 | length: 0.0 | width: 0.0 | height: 0.0 | cube: 0.0 | cube_per_container: 0 | weight: 60.8105 | weight_per_container: 423 | water_transport: 40ft | land_transport: Van | Produced by: source-6, source-21, source-17 |
# 	[17706] MATERIAL    Fender | quantity: 4 | length: 1.102743902 | width: 0.198170732 | height: 0.245731707 | cube: 1.8949463 | cube_per_container: 1252 | weight: 172.1576667 | weight_per_container: 149 | water_transport: 40ft | land_transport: Van | Produced by: source-21, source-32, source-6 |
# 	[17707] MATERIAL    Bucket | quantity: 1 | length: 0.396341463 | width: 0.857926829 | height: 0.301694423 | cube: 3.62 | cube_per_container: 655 | weight: 1697.517 | weight_per_container: 15 | water_transport: 40ft | land_transport: Van | Produced by: source-3, source-21, source-17 |
# 	[17708] MATERIAL    Tires | quantity: 4 | length: 0.491463415 | width: 0.186628049 | height: 0.491463415 | cube: 1.590672724 | cube_per_container: 1492 | weight: 505.0036667 | weight_per_container: 51 | water_transport: 40ft | land_transport: Van | Produced by: source-35, source-21, source-17 |
# 	[17709] PRODUCER    source-1 | source-1 |
# 	[17710] PRODUCER    source-2 | source-2 |
# 	[17711] PRODUCER    source-3 | source-3 | Produces: Bucket |
# 	[17712] PRODUCER    source-4 | source-4 |
# 	[17713] PRODUCER    source-5 | source-5 |
# 	[17714] PRODUCER    source-6 | source-6 | 163786/unit | 1250 units capacity | Produces: Lights, Guard, CA, Linkage, Radio, Axles, Seat, Fender |
# 	[17715] PRODUCER    source-7 | source-7 |
# 	[17716] PRODUCER    source-8 | source-8 |
# 	[17717] PRODUCER    source-9 | source-9 |
# 	[17718] PRODUCER    source-10 | source-10 |
# 	[17719] PRODUCER    source-11 | source-11 |
# 	[17720] PRODUCER    source-12 | source-12 |
# 	[17721] PRODUCER    source-13 | source-13 |
# 	[17722] PRODUCER    source-14 | source-14 |
# 	[17723] PRODUCER    source-15 | source-15 |
# 	[17724] PRODUCER    source-16 | source-16 |
# 	[17725] PRODUCER    source-17 | source-17 | 117758/unit | 80 units capacity | Produces: Lights, CA, Guard, Tires, Axles, Radio, Bucket, Seat |
# 	[17726] PRODUCER    source-18 | source-18 |
# 	[17727] PRODUCER    source-19 | source-19 |
# 	[17728] PRODUCER    source-20 | source-20 |
# 	[17729] PRODUCER    source-21 | source-21 | 150132/unit | 95 units capacity | Produces: Lights, Guard, CA, Linkage, Tires, Radio, Axles, Bucket, Seat, Fender |
# 	[17730] PRODUCER    source-22 | source-22 |
# 	[17731] PRODUCER    source-23 | source-23 |
# 	[17732] PRODUCER    source-24 | source-24 |
# 	[17733] PRODUCER    source-25 | source-25 |
# 	[17734] PRODUCER    source-26 | source-26 |
# 	[17735] PRODUCER    source-27 | source-27 |
# 	[17736] PRODUCER    source-28 | source-28 |
# 	[17737] PRODUCER    source-29 | source-29 |
# 	[17738] PRODUCER    source-30 | source-30 |
# 	[17739] PRODUCER    source-31 | source-31 |
# 	[17740] PRODUCER    source-32 | source-32 | Produces: Fender |
# 	[17741] PRODUCER    source-33 | source-33 |
# 	[17742] PRODUCER    source-34 | source-34 |
# 	[17743] PRODUCER    source-35 | source-35 | Produces: Tires |
# 	[17744] PRODUCER    source-36 | source-36 |
# 	[17745] PRODUCER    source-37 | source-37 |
# 	[17746] PRODUCER    source-38 | source-38 |
# 	[17747] PRODUCER    source-39 | source-39 |
# 	[17748] PRODUCER    source-40 | source-40 |

# %% [markdown]
# # Step 2: Creating Graph

# %%
net = SupplyNetwork()
net.add_DB(DB)

# %%
# Transportation Graph
transportation_graph = net.create_knowledge_graph(as_label=False)

# %%
# Supply Flow
supply_flow = net.create_supply_flow(as_label=False)

# %%
# Knowledge Graph
knowledge_graph = net.create_knowledge_graph(as_label=False)

# %% [markdown]
# # Step 3: Analysis
#
# - **Transportation Graph:** Only Transportation Data
#
# - **Supply Flow Graph:** All Data, except transportation
# - **Knowledge Graph:** All Data, complete graph
